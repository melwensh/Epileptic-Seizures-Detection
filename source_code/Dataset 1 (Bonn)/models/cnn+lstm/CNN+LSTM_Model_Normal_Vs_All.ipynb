# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv1D, MaxPooling1D, LSTM, Dense, Dropout, BatchNormalization
)
from tensorflow.keras.optimizers import Adam

PREPROCESSING_DIR = r"Preprocessing_Updated_Kfold" 
N_FOLDS = 5
RESULTS_DIR = "results(Normal_VS_All)"

os.makedirs(RESULTS_DIR, exist_ok=True)

def hybrid_focal_loss(alpha=0.25, gamma=2.0, bce_weight=0.5):
    
    def loss(y_true, y_pred):
        bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)

        y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
        focal = -alpha * (1 - y_pred) ** gamma * y_true * K.log(y_pred) \
                - (1 - alpha) * y_pred ** gamma * (1 - y_true) * K.log(1 - y_pred)

        focal = K.mean(focal, axis=-1)

        return bce_weight * bce + (1 - bce_weight) * focal

    return loss

def build_cnn_lstm(input_length):
    model = Sequential([
        Conv1D(32, kernel_size=7, activation='relu', input_shape=(input_length, 1)),
        BatchNormalization(),
        MaxPooling1D(2),
        Dropout(0.2),

        Conv1D(64, kernel_size=5, activation='relu'),
        BatchNormalization(),
        MaxPooling1D(2),
        Dropout(0.3),

        Conv1D(128, kernel_size=3, activation='relu'),
        BatchNormalization(),
        MaxPooling1D(2),
        Dropout(0.4),
        
        LSTM(64, return_sequences=False),

        Dense(64, activation='relu'),
        Dropout(0.4),

        Dense(1, activation='sigmoid')
    ])

    model.compile(
        optimizer=Adam(1e-4),
        loss=hybrid_focal_loss(alpha=0.25, gamma=2.0, bce_weight=0.5),
        metrics=['accuracy']
    )
    return model

def augment_signal(signal):
    noise = np.random.normal(0, 0.005, signal.shape)
    signal_noisy = signal + noise

    shift = np.random.randint(-5, 5)
    signal_shifted = np.roll(signal_noisy, shift)

    scale = np.random.uniform(0.97, 1.03)
    signal_scaled = signal_shifted * scale

    return signal_scaled

def augment_batch(X, y):
    X_aug = []
    y_aug = []

    for i in range(len(X)):
        X_aug.append(X[i])
        y_aug.append(y[i])

        X_aug.append(augment_signal(X[i]))
        y_aug.append(y[i])

    return np.array(X_aug), np.array(y_aug)

acc_per_fold = []
conf_matrices = []

for fold_no in range(N_FOLDS):
    print(f"\n{'='*60}")
    print(f"Fold {fold_no + 1}/{N_FOLDS}")
    print(f"{'='*60}")

    X_train_full = np.load(os.path.join(PREPROCESSING_DIR, f"fold_{fold_no}_X_train.npy"), allow_pickle=True)
    y_train_full = np.load(os.path.join(PREPROCESSING_DIR, f"fold_{fold_no}_y_train.npy"), allow_pickle=True)
    X_test = np.load(os.path.join(PREPROCESSING_DIR, f"fold_{fold_no}_X_test.npy"), allow_pickle=True)
    y_test = np.load(os.path.join(PREPROCESSING_DIR, f"fold_{fold_no}_y_test.npy"), allow_pickle=True)
    
    if X_train_full.dtype == object:
        X_train_full = np.vstack(X_train_full).astype(np.float32)
    if X_test.dtype == object:
        X_test = np.vstack(X_test).astype(np.float32)
    
    X_train_full = X_train_full.astype(np.float32)
    X_test = X_test.astype(np.float32)
    y_train_full = y_train_full.astype(np.int32)
    y_test = y_test.astype(np.int32)

    
    y_train_full_binary = np.where(y_train_full == 0, 0, 1)
    y_test_binary = np.where(y_test == 0, 0, 1)

    print(f"Original labels - Train: {np.unique(y_train_full, return_counts=True)}")
    print(f"Binary labels - Train: {np.unique(y_train_full_binary, return_counts=True)}")
    print(f"Binary labels - Test: {np.unique(y_test_binary, return_counts=True)}")

    X_train, X_val, y_train, y_val = train_test_split(
        X_train_full, y_train_full_binary, 
        test_size=0.1765, 
        stratify=y_train_full_binary, 
        random_state=42
    )

    X_train, y_train = augment_batch(X_train, y_train)

    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

    print(f"\n Data shapes:")
    print(f"  Train: {X_train.shape}")
    print(f"  Val:   {X_val.shape}")
    print(f"  Test:  {X_test.shape}")

    model = build_cnn_lstm(X_train.shape[1])
    
    if fold_no == 0:  
        model.summary()

    unique_classes = np.unique(y_train)
    cw = compute_class_weight('balanced', classes=unique_classes, y=y_train)
    class_weights = {cls: weight for cls, weight in zip(unique_classes, cw)}
    print(f"\n Class weights: {class_weights}")

    print(f"\n Training Fold {fold_no + 1}...")
    history = model.fit(
        X_train, y_train,
        epochs=40,
        batch_size=32,
        validation_data=(X_val, y_val),
        class_weight=class_weights,
        verbose=1
    )

    test_loss, test_acc = model.evaluate(X_test, y_test_binary, verbose=0)
    acc_per_fold.append(test_acc)
    print(f"\nFold {fold_no + 1} - Test Accuracy: {test_acc:.4f}")

    weight_path = os.path.join(RESULTS_DIR, f"cnn_lstm_fold{fold_no + 1}.weights.h5")
    model.save_weights(weight_path)
    print(f"Weights saved to {weight_path}")

    y_pred = (model.predict(X_test, verbose=0) > 0.5).astype("int32").flatten()
    cm = confusion_matrix(y_test_binary, y_pred)
    conf_matrices.append(cm)

    plt.figure(figsize=(6, 5))
    sns.heatmap(
        cm, annot=True, fmt='d', cmap='Blues',
        xticklabels=['NORMAL', 'ABNORMAL'], 
        yticklabels=['NORMAL', 'ABNORMAL']
    )
    plt.title(f"Fold {fold_no + 1} Confusion Matrix\nAccuracy: {test_acc:.4f}")
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.savefig(os.path.join(RESULTS_DIR, f"cnn_lstm_conf_fold{fold_no + 1}.png"))
    plt.close()

print("\n" + "="*60)
print("FINAL RESULTS")
print("="*60)
print(f"Mean Accuracy across all folds: {np.mean(acc_per_fold):.4f} =+ {np.std(acc_per_fold):.4f}")
print(f"Accuracy per fold: {[f'{acc:.4f}' for acc in acc_per_fold]}")

total_cm = np.sum(conf_matrices, axis=0)

plt.figure(figsize=(6, 5))
sns.heatmap(
    total_cm, annot=True, fmt='d', cmap='Greens',
    xticklabels=['NORMAL', 'ABNORMAL'], 
    yticklabels=['NORMAL', 'ABNORMAL']
)
plt.title("Overall Confusion Matrix (All Folds)")
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "cnn_lstm_conf_overall.png"))
plt.show()

tn, fp, fn, tp = total_cm.ravel()

overall_accuracy = (tp + tn) / np.sum(total_cm)
overall_precision = tp / (tp + fp) if (tp + fp) > 0 else 0
overall_recall = tp / (tp + fn) if (tp + fn) > 0 else 0
overall_f1 = 2 * overall_precision * overall_recall / (overall_precision + overall_recall) if (overall_precision + overall_recall) > 0 else 0

print("\n Overall Metrics (All Folds Combined):")
print(f"  Accuracy : {overall_accuracy:.4f}")
print(f"  Precision: {overall_precision:.4f}")
print(f"  Recall   : {overall_recall:.4f}")
print(f"  F1-score : {overall_f1:.4f}")

print("\n CNN+LSTM Training Completed!")
# Out:
# ============================================================
# Fold 1/5
# ============================================================
# Original labels - Train: (array([0, 1, 2], dtype=int32), array([1280, 1280,  640]))
# Binary labels - Train: (array([0, 1]), array([1280, 1920]))
# Binary labels - Test: (array([0, 1]), array([320, 480]))
#
#  Data shapes:
#   Train: (5270, 868, 1)
#   Val:   (565, 868, 1)
#   Test:  (800, 868, 1)
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 862, 32)        │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 862, 32)        │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 431, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 431, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 427, 64)        │        10,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 427, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 213, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 213, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 211, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 211, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 105, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 105, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 89,793 (350.75 KB)
#  Trainable params: 89,345 (349.00 KB)
#  Non-trainable params: 448 (1.75 KB)
#  Class weights: {np.int64(0): np.float64(1.25), np.int64(1): np.float64(0.8333333333333334)}
#
#  Training Fold 1...
# Epoch 1/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 100ms/step - accuracy: 0.7106 - loss: 0.3121 - val_accuracy: 0.6000 - val_loss: 0.4058
# Epoch 2/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 16s 97ms/step - accuracy: 0.8603 - loss: 0.2033 - val_accuracy: 0.7186 - val_loss: 0.3492
# Epoch 3/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 16s 97ms/step - accuracy: 0.8981 - loss: 0.1555 - val_accuracy: 0.9150 - val_loss: 0.1486
# Epoch 4/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 16s 97ms/step - accuracy: 0.9228 - loss: 0.1252 - val_accuracy: 0.9363 - val_loss: 0.0986
# Epoch 5/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 16s 95ms/step - accuracy: 0.9262 - loss: 0.1153 - val_accuracy: 0.9487 - val_loss: 0.0830
# Epoch 6/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 93ms/step - accuracy: 0.9324 - loss: 0.1073 - val_accuracy: 0.9504 - val_loss: 0.0734
# Epoch 7/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 91ms/step - accuracy: 0.9323 - loss: 0.0982 - val_accuracy: 0.9487 - val_loss: 0.0759
# Epoch 8/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 103ms/step - accuracy: 0.9366 - loss: 0.0903 - val_accuracy: 0.9558 - val_loss: 0.0762
# Epoch 9/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 90ms/step - accuracy: 0.9412 - loss: 0.0884 - val_accuracy: 0.9611 - val_loss: 0.0804
# Epoch 10/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 14s 87ms/step - accuracy: 0.9361 - loss: 0.0862 - val_accuracy: 0.9681 - val_loss: 0.0711
# Epoch 11/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 14s 84ms/step - accuracy: 0.9440 - loss: 0.0796 - val_accuracy: 0.9558 - val_loss: 0.0878
# Epoch 12/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 14s 86ms/step - accuracy: 0.9416 - loss: 0.0793 - val_accuracy: 0.9664 - val_loss: 0.0706
# Epoch 13/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 16s 95ms/step - accuracy: 0.9444 - loss: 0.0768 - val_accuracy: 0.9717 - val_loss: 0.0707
# Epoch 14/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 113ms/step - accuracy: 0.9484 - loss: 0.0701 - val_accuracy: 0.9717 - val_loss: 0.0712
# Epoch 15/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 101ms/step - accuracy: 0.9435 - loss: 0.0727 - val_accuracy: 0.9646 - val_loss: 0.0751
# Epoch 16/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 16s 98ms/step - accuracy: 0.9446 - loss: 0.0764 - val_accuracy: 0.9681 - val_loss: 0.0713
# Epoch 17/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 91ms/step - accuracy: 0.9450 - loss: 0.0691 - val_accuracy: 0.9735 - val_loss: 0.0637
# Epoch 18/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 91ms/step - accuracy: 0.9442 - loss: 0.0747 - val_accuracy: 0.9735 - val_loss: 0.0649
# Epoch 19/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 147ms/step - accuracy: 0.9516 - loss: 0.0644 - val_accuracy: 0.9699 - val_loss: 0.0694
# Epoch 20/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 156ms/step - accuracy: 0.9505 - loss: 0.0627 - val_accuracy: 0.9717 - val_loss: 0.0749
# Epoch 21/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 16s 95ms/step - accuracy: 0.9463 - loss: 0.0672 - val_accuracy: 0.9770 - val_loss: 0.0592
# Epoch 22/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 90ms/step - accuracy: 0.9495 - loss: 0.0652 - val_accuracy: 0.9735 - val_loss: 0.0593
# Epoch 23/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - accuracy: 0.9491 - loss: 0.0648 - val_accuracy: 0.9735 - val_loss: 0.0629
# Epoch 24/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 147ms/step - accuracy: 0.9512 - loss: 0.0629 - val_accuracy: 0.9699 - val_loss: 0.0645
# Epoch 25/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 141ms/step - accuracy: 0.9554 - loss: 0.0579 - val_accuracy: 0.9735 - val_loss: 0.0668
# Epoch 26/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 20s 118ms/step - accuracy: 0.9543 - loss: 0.0609 - val_accuracy: 0.9770 - val_loss: 0.0578
# Epoch 27/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 144ms/step - accuracy: 0.9571 - loss: 0.0575 - val_accuracy: 0.9735 - val_loss: 0.0605
# Epoch 28/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 153ms/step - accuracy: 0.9569 - loss: 0.0570 - val_accuracy: 0.9717 - val_loss: 0.0707
# Epoch 29/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 140ms/step - accuracy: 0.9584 - loss: 0.0536 - val_accuracy: 0.9646 - val_loss: 0.0805
# Epoch 30/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 19s 115ms/step - accuracy: 0.9577 - loss: 0.0582 - val_accuracy: 0.9717 - val_loss: 0.0730
# Epoch 31/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 19s 116ms/step - accuracy: 0.9569 - loss: 0.0516 - val_accuracy: 0.9735 - val_loss: 0.0758
# Epoch 32/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 135ms/step - accuracy: 0.9630 - loss: 0.0535 - val_accuracy: 0.9752 - val_loss: 0.0641
# Epoch 33/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 146ms/step - accuracy: 0.9653 - loss: 0.0485 - val_accuracy: 0.9770 - val_loss: 0.0706
# Epoch 34/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 152ms/step - accuracy: 0.9645 - loss: 0.0486 - val_accuracy: 0.9611 - val_loss: 0.0966
# Epoch 35/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 150ms/step - accuracy: 0.9634 - loss: 0.0505 - val_accuracy: 0.9611 - val_loss: 0.0947
# Epoch 36/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 152ms/step - accuracy: 0.9664 - loss: 0.0451 - val_accuracy: 0.9558 - val_loss: 0.1194
# Epoch 37/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 136ms/step - accuracy: 0.9655 - loss: 0.0471 - val_accuracy: 0.9717 - val_loss: 0.0784
# Epoch 38/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 141ms/step - accuracy: 0.9628 - loss: 0.0495 - val_accuracy: 0.9628 - val_loss: 0.1019
# Epoch 39/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 21s 126ms/step - accuracy: 0.9660 - loss: 0.0466 - val_accuracy: 0.9681 - val_loss: 0.0903
# Epoch 40/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 143ms/step - accuracy: 0.9617 - loss: 0.0529 - val_accuracy: 0.9646 - val_loss: 0.0934
#
# Fold 1 - Test Accuracy: 0.9550
# Weights saved to results(Normal_VS_All)\cnn_lstm_fold1.weights.h5
#
# ============================================================
# Fold 2/5
# ============================================================
# Original labels - Train: (array([0, 1, 2], dtype=int32), array([1280, 1280,  640]))
# Binary labels - Train: (array([0, 1]), array([1280, 1920]))
# Binary labels - Test: (array([0, 1]), array([320, 480]))
#
#  Data shapes:
#   Train: (5270, 868, 1)
#   Val:   (565, 868, 1)
#   Test:  (800, 868, 1)
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#  Class weights: {np.int64(0): np.float64(1.25), np.int64(1): np.float64(0.8333333333333334)}
#
#  Training Fold 2...
# Epoch 1/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 67s 164ms/step - accuracy: 0.7391 - loss: 0.3085 - val_accuracy: 0.6018 - val_loss: 0.4113
# Epoch 2/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 140ms/step - accuracy: 0.8617 - loss: 0.1974 - val_accuracy: 0.7735 - val_loss: 0.3059
# Epoch 3/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 139ms/step - accuracy: 0.8985 - loss: 0.1560 - val_accuracy: 0.9310 - val_loss: 0.1131
# Epoch 4/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 140ms/step - accuracy: 0.9203 - loss: 0.1275 - val_accuracy: 0.9416 - val_loss: 0.0921
# Epoch 5/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 42s 146ms/step - accuracy: 0.9290 - loss: 0.1192 - val_accuracy: 0.9487 - val_loss: 0.0786
# Epoch 6/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 139ms/step - accuracy: 0.9300 - loss: 0.1075 - val_accuracy: 0.9451 - val_loss: 0.0793
# Epoch 7/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 21s 129ms/step - accuracy: 0.9440 - loss: 0.0979 - val_accuracy: 0.9451 - val_loss: 0.0848
# Epoch 8/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 139ms/step - accuracy: 0.9393 - loss: 0.0957 - val_accuracy: 0.9451 - val_loss: 0.0808
# Epoch 9/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - accuracy: 0.9450 - loss: 0.0870 - val_accuracy: 0.9522 - val_loss: 0.0729
# Epoch 10/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 140ms/step - accuracy: 0.9431 - loss: 0.0831 - val_accuracy: 0.9558 - val_loss: 0.0626
# Epoch 11/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 144ms/step - accuracy: 0.9448 - loss: 0.0792 - val_accuracy: 0.9593 - val_loss: 0.0572
# Epoch 12/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 139ms/step - accuracy: 0.9471 - loss: 0.0834 - val_accuracy: 0.9593 - val_loss: 0.0626
# Epoch 13/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 136ms/step - accuracy: 0.9490 - loss: 0.0746 - val_accuracy: 0.9699 - val_loss: 0.0486
# Epoch 14/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 42s 138ms/step - accuracy: 0.9509 - loss: 0.0720 - val_accuracy: 0.9664 - val_loss: 0.0490
# Epoch 15/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 42s 142ms/step - accuracy: 0.9588 - loss: 0.0660 - val_accuracy: 0.9717 - val_loss: 0.0465
# Epoch 16/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 143ms/step - accuracy: 0.9548 - loss: 0.0682 - val_accuracy: 0.9699 - val_loss: 0.0477
# Epoch 17/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 141ms/step - accuracy: 0.9565 - loss: 0.0631 - val_accuracy: 0.9699 - val_loss: 0.0454
# Epoch 18/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 130ms/step - accuracy: 0.9539 - loss: 0.0648 - val_accuracy: 0.9717 - val_loss: 0.0438
# Epoch 19/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 19s 117ms/step - accuracy: 0.9584 - loss: 0.0565 - val_accuracy: 0.9699 - val_loss: 0.0433
# Epoch 20/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 139ms/step - accuracy: 0.9579 - loss: 0.0609 - val_accuracy: 0.9752 - val_loss: 0.0427
# Epoch 21/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.9579 - loss: 0.0589 - val_accuracy: 0.9717 - val_loss: 0.0442
# Epoch 22/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 155ms/step - accuracy: 0.9634 - loss: 0.0515 - val_accuracy: 0.9699 - val_loss: 0.0444
# Epoch 23/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - accuracy: 0.9607 - loss: 0.0555 - val_accuracy: 0.9752 - val_loss: 0.0456
# Epoch 24/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 140ms/step - accuracy: 0.9639 - loss: 0.0543 - val_accuracy: 0.9699 - val_loss: 0.0481
# Epoch 25/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 150ms/step - accuracy: 0.9658 - loss: 0.0480 - val_accuracy: 0.9646 - val_loss: 0.0533
# Epoch 26/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 34s 107ms/step - accuracy: 0.9626 - loss: 0.0531 - val_accuracy: 0.9664 - val_loss: 0.0502
# Epoch 27/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 14s 87ms/step - accuracy: 0.9664 - loss: 0.0503 - val_accuracy: 0.9628 - val_loss: 0.0540
# Epoch 28/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - accuracy: 0.9664 - loss: 0.0493 - val_accuracy: 0.9611 - val_loss: 0.0536
# Epoch 29/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 107ms/step - accuracy: 0.9662 - loss: 0.0505 - val_accuracy: 0.9522 - val_loss: 0.0652
# Epoch 30/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 21s 126ms/step - accuracy: 0.9696 - loss: 0.0475 - val_accuracy: 0.9558 - val_loss: 0.0589
# Epoch 31/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 135ms/step - accuracy: 0.9683 - loss: 0.0444 - val_accuracy: 0.9628 - val_loss: 0.0582
# Epoch 32/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 145ms/step - accuracy: 0.9636 - loss: 0.0511 - val_accuracy: 0.9504 - val_loss: 0.0635
# Epoch 33/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 153ms/step - accuracy: 0.9683 - loss: 0.0446 - val_accuracy: 0.9522 - val_loss: 0.0668
# Epoch 34/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 20s 122ms/step - accuracy: 0.9702 - loss: 0.0443 - val_accuracy: 0.9735 - val_loss: 0.0534
# Epoch 35/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 139ms/step - accuracy: 0.9674 - loss: 0.0474 - val_accuracy: 0.9363 - val_loss: 0.0825
# Epoch 36/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 145ms/step - accuracy: 0.9685 - loss: 0.0437 - val_accuracy: 0.9558 - val_loss: 0.0595
# Epoch 37/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 20s 117ms/step - accuracy: 0.9742 - loss: 0.0378 - val_accuracy: 0.9504 - val_loss: 0.0797
# Epoch 38/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 141ms/step - accuracy: 0.9706 - loss: 0.0381 - val_accuracy: 0.9451 - val_loss: 0.0889
# Epoch 39/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 103ms/step - accuracy: 0.9757 - loss: 0.0369 - val_accuracy: 0.9628 - val_loss: 0.0645
# Epoch 40/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 14s 86ms/step - accuracy: 0.9763 - loss: 0.0377 - val_accuracy: 0.9522 - val_loss: 0.0731
#
# Fold 2 - Test Accuracy: 0.9375
# Weights saved to results(Normal_VS_All)\cnn_lstm_fold2.weights.h5
#
# ============================================================
# Fold 3/5
# ============================================================
# Original labels - Train: (array([0, 1, 2], dtype=int32), array([1280, 1280,  640]))
# Binary labels - Train: (array([0, 1]), array([1280, 1920]))
# Binary labels - Test: (array([0, 1]), array([320, 480]))
#
#  Data shapes:
#   Train: (5270, 868, 1)
#   Val:   (565, 868, 1)
#   Test:  (800, 868, 1)
#
#  Class weights: {np.int64(0): np.float64(1.25), np.int64(1): np.float64(0.8333333333333334)}
#
#  Training Fold 3...
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 32s 153ms/step - accuracy: 0.7469 - loss: 0.2908 - val_accuracy: 0.6088 - val_loss: 0.3476
# Epoch 2/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 148ms/step - accuracy: 0.8750 - loss: 0.1838 - val_accuracy: 0.7982 - val_loss: 0.2293
# Epoch 3/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 146ms/step - accuracy: 0.9030 - loss: 0.1453 - val_accuracy: 0.9257 - val_loss: 0.1188
# Epoch 4/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 19s 117ms/step - accuracy: 0.9372 - loss: 0.1134 - val_accuracy: 0.9345 - val_loss: 0.1026
# Epoch 5/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 143ms/step - accuracy: 0.9389 - loss: 0.1023 - val_accuracy: 0.9310 - val_loss: 0.0973
# Epoch 6/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 44s 159ms/step - accuracy: 0.9429 - loss: 0.0957 - val_accuracy: 0.9487 - val_loss: 0.0848
# Epoch 7/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 27s 163ms/step - accuracy: 0.9414 - loss: 0.0920 - val_accuracy: 0.9487 - val_loss: 0.0818
# Epoch 8/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - accuracy: 0.9476 - loss: 0.0883 - val_accuracy: 0.9522 - val_loss: 0.0783
# Epoch 9/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 157ms/step - accuracy: 0.9454 - loss: 0.0850 - val_accuracy: 0.9664 - val_loss: 0.0617
# Epoch 10/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 142ms/step - accuracy: 0.9484 - loss: 0.0779 - val_accuracy: 0.9646 - val_loss: 0.0568
# Epoch 11/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 19s 116ms/step - accuracy: 0.9552 - loss: 0.0677 - val_accuracy: 0.9681 - val_loss: 0.0531
# Epoch 12/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 129ms/step - accuracy: 0.9565 - loss: 0.0658 - val_accuracy: 0.9717 - val_loss: 0.0540
# Epoch 13/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 16s 98ms/step - accuracy: 0.9516 - loss: 0.0693 - val_accuracy: 0.9717 - val_loss: 0.0521
# Epoch 14/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 93ms/step - accuracy: 0.9562 - loss: 0.0652 - val_accuracy: 0.9770 - val_loss: 0.0511
# Epoch 15/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 88ms/step - accuracy: 0.9594 - loss: 0.0636 - val_accuracy: 0.9752 - val_loss: 0.0527
# Epoch 16/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 137ms/step - accuracy: 0.9651 - loss: 0.0580 - val_accuracy: 0.9752 - val_loss: 0.0496
# Epoch 17/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 146ms/step - accuracy: 0.9615 - loss: 0.0597 - val_accuracy: 0.9752 - val_loss: 0.0514
# Epoch 18/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 21s 124ms/step - accuracy: 0.9613 - loss: 0.0574 - val_accuracy: 0.9752 - val_loss: 0.0528
# Epoch 19/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 142ms/step - accuracy: 0.9664 - loss: 0.0560 - val_accuracy: 0.9770 - val_loss: 0.0539
# Epoch 20/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 136ms/step - accuracy: 0.9598 - loss: 0.0608 - val_accuracy: 0.9752 - val_loss: 0.0501
# Epoch 21/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - accuracy: 0.9674 - loss: 0.0514 - val_accuracy: 0.9770 - val_loss: 0.0534
# Epoch 22/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 142ms/step - accuracy: 0.9676 - loss: 0.0500 - val_accuracy: 0.9805 - val_loss: 0.0456
# Epoch 23/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 135ms/step - accuracy: 0.9685 - loss: 0.0503 - val_accuracy: 0.9770 - val_loss: 0.0453
# Epoch 24/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 142ms/step - accuracy: 0.9693 - loss: 0.0441 - val_accuracy: 0.9770 - val_loss: 0.0534
# Epoch 25/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 137ms/step - accuracy: 0.9676 - loss: 0.0475 - val_accuracy: 0.9770 - val_loss: 0.0475
# Epoch 26/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 42s 140ms/step - accuracy: 0.9708 - loss: 0.0427 - val_accuracy: 0.9770 - val_loss: 0.0426
# Epoch 27/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 89ms/step - accuracy: 0.9691 - loss: 0.0443 - val_accuracy: 0.9770 - val_loss: 0.0526
# Epoch 28/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 14s 82ms/step - accuracy: 0.9713 - loss: 0.0435 - val_accuracy: 0.9752 - val_loss: 0.0492
# Epoch 29/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 13s 81ms/step - accuracy: 0.9719 - loss: 0.0426 - val_accuracy: 0.9788 - val_loss: 0.0537
# Epoch 30/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 140ms/step - accuracy: 0.9712 - loss: 0.0457 - val_accuracy: 0.9752 - val_loss: 0.0574
# Epoch 31/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 130ms/step - accuracy: 0.9719 - loss: 0.0385 - val_accuracy: 0.9805 - val_loss: 0.0666
# Epoch 32/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 109ms/step - accuracy: 0.9715 - loss: 0.0424 - val_accuracy: 0.9788 - val_loss: 0.0521
# Epoch 33/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 108ms/step - accuracy: 0.9734 - loss: 0.0417 - val_accuracy: 0.9788 - val_loss: 0.0588
# Epoch 34/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 21s 128ms/step - accuracy: 0.9753 - loss: 0.0345 - val_accuracy: 0.9788 - val_loss: 0.0605
# Epoch 35/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - accuracy: 0.9715 - loss: 0.0401 - val_accuracy: 0.9770 - val_loss: 0.0645
# Epoch 36/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 143ms/step - accuracy: 0.9736 - loss: 0.0400 - val_accuracy: 0.9788 - val_loss: 0.0655
# Epoch 37/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 145ms/step - accuracy: 0.9755 - loss: 0.0358 - val_accuracy: 0.9699 - val_loss: 0.0781
# Epoch 38/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 145ms/step - accuracy: 0.9742 - loss: 0.0387 - val_accuracy: 0.9788 - val_loss: 0.0462
# Epoch 39/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 38s 128ms/step - accuracy: 0.9738 - loss: 0.0352 - val_accuracy: 0.9628 - val_loss: 0.0877
# Epoch 40/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 20s 122ms/step - accuracy: 0.9805 - loss: 0.0304 - val_accuracy: 0.9788 - val_loss: 0.0533
#
# Fold 3 - Test Accuracy: 0.9775
# Weights saved to results(Normal_VS_All)\cnn_lstm_fold3.weights.h5
#
# ============================================================
# Fold 4/5
# ============================================================
# Original labels - Train: (array([0, 1, 2], dtype=int32), array([1280, 1280,  640]))
# Binary labels - Train: (array([0, 1]), array([1280, 1920]))
# Binary labels - Test: (array([0, 1]), array([320, 480]))
#
#  Data shapes:
#   Train: (5270, 868, 1)
#   Val:   (565, 868, 1)
#   Test:  (800, 868, 1)
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#  Class weights: {np.int64(0): np.float64(1.25), np.int64(1): np.float64(0.8333333333333334)}
#
#  Training Fold 4...
# Epoch 1/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 70s 179ms/step - accuracy: 0.7167 - loss: 0.3043 - val_accuracy: 0.6000 - val_loss: 0.4103
# Epoch 2/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 146ms/step - accuracy: 0.8624 - loss: 0.2033 - val_accuracy: 0.6814 - val_loss: 0.3354
# Epoch 3/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 146ms/step - accuracy: 0.9019 - loss: 0.1554 - val_accuracy: 0.8991 - val_loss: 0.1493
# Epoch 4/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 152ms/step - accuracy: 0.9213 - loss: 0.1224 - val_accuracy: 0.9080 - val_loss: 0.1347
# Epoch 5/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 20s 123ms/step - accuracy: 0.9288 - loss: 0.1117 - val_accuracy: 0.8903 - val_loss: 0.1504
# Epoch 6/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 133ms/step - accuracy: 0.9328 - loss: 0.1075 - val_accuracy: 0.8761 - val_loss: 0.1695
# Epoch 7/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 140ms/step - accuracy: 0.9351 - loss: 0.0952 - val_accuracy: 0.8761 - val_loss: 0.1795
# Epoch 8/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 140ms/step - accuracy: 0.9342 - loss: 0.0959 - val_accuracy: 0.8973 - val_loss: 0.1508
# Epoch 9/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - accuracy: 0.9452 - loss: 0.0819 - val_accuracy: 0.8903 - val_loss: 0.1735
# Epoch 10/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 135ms/step - accuracy: 0.9395 - loss: 0.0891 - val_accuracy: 0.9080 - val_loss: 0.1474
# Epoch 11/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 139ms/step - accuracy: 0.9478 - loss: 0.0823 - val_accuracy: 0.8920 - val_loss: 0.1735
# Epoch 12/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 137ms/step - accuracy: 0.9478 - loss: 0.0725 - val_accuracy: 0.9239 - val_loss: 0.1298
# Epoch 13/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 42s 139ms/step - accuracy: 0.9491 - loss: 0.0736 - val_accuracy: 0.9363 - val_loss: 0.1104
# Epoch 14/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 141ms/step - accuracy: 0.9501 - loss: 0.0719 - val_accuracy: 0.9239 - val_loss: 0.1412
# Epoch 15/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 140ms/step - accuracy: 0.9471 - loss: 0.0708 - val_accuracy: 0.9522 - val_loss: 0.0926
# Epoch 16/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 137ms/step - accuracy: 0.9531 - loss: 0.0690 - val_accuracy: 0.9292 - val_loss: 0.1346
# Epoch 17/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 140ms/step - accuracy: 0.9509 - loss: 0.0685 - val_accuracy: 0.9451 - val_loss: 0.1042
# Epoch 18/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 137ms/step - accuracy: 0.9573 - loss: 0.0649 - val_accuracy: 0.9469 - val_loss: 0.1016
# Epoch 19/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 140ms/step - accuracy: 0.9564 - loss: 0.0597 - val_accuracy: 0.9451 - val_loss: 0.1064
# Epoch 20/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 20s 119ms/step - accuracy: 0.9535 - loss: 0.0646 - val_accuracy: 0.9451 - val_loss: 0.1072
# Epoch 21/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 20s 119ms/step - accuracy: 0.9584 - loss: 0.0579 - val_accuracy: 0.9540 - val_loss: 0.1040
# Epoch 22/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 136ms/step - accuracy: 0.9567 - loss: 0.0578 - val_accuracy: 0.9593 - val_loss: 0.0967
# Epoch 23/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 136ms/step - accuracy: 0.9541 - loss: 0.0613 - val_accuracy: 0.9540 - val_loss: 0.0987
# Epoch 24/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - accuracy: 0.9594 - loss: 0.0567 - val_accuracy: 0.9575 - val_loss: 0.0918
# Epoch 25/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 153ms/step - accuracy: 0.9588 - loss: 0.0595 - val_accuracy: 0.9593 - val_loss: 0.0941
# Epoch 26/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 27s 162ms/step - accuracy: 0.9575 - loss: 0.0557 - val_accuracy: 0.9593 - val_loss: 0.0967
# Epoch 27/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.9689 - loss: 0.0480 - val_accuracy: 0.9664 - val_loss: 0.0842
# Epoch 28/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 148ms/step - accuracy: 0.9647 - loss: 0.0524 - val_accuracy: 0.9593 - val_loss: 0.1033
# Epoch 29/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 148ms/step - accuracy: 0.9666 - loss: 0.0469 - val_accuracy: 0.9664 - val_loss: 0.0882
# Epoch 30/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 147ms/step - accuracy: 0.9632 - loss: 0.0509 - val_accuracy: 0.9664 - val_loss: 0.0755
# Epoch 31/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 20s 121ms/step - accuracy: 0.9681 - loss: 0.0458 - val_accuracy: 0.9646 - val_loss: 0.0708
# Epoch 32/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 109ms/step - accuracy: 0.9626 - loss: 0.0528 - val_accuracy: 0.9681 - val_loss: 0.0757
# Epoch 33/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 105ms/step - accuracy: 0.9676 - loss: 0.0498 - val_accuracy: 0.9699 - val_loss: 0.0686
# Epoch 34/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 104ms/step - accuracy: 0.9639 - loss: 0.0509 - val_accuracy: 0.9681 - val_loss: 0.0744
# Epoch 35/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - accuracy: 0.9607 - loss: 0.0523 - val_accuracy: 0.9717 - val_loss: 0.0652
# Epoch 36/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 92ms/step - accuracy: 0.9651 - loss: 0.0520 - val_accuracy: 0.9664 - val_loss: 0.0741
# Epoch 37/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 106ms/step - accuracy: 0.9672 - loss: 0.0447 - val_accuracy: 0.9646 - val_loss: 0.0890
# Epoch 38/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 99ms/step - accuracy: 0.9670 - loss: 0.0482 - val_accuracy: 0.9699 - val_loss: 0.0740
# Epoch 39/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 106ms/step - accuracy: 0.9649 - loss: 0.0448 - val_accuracy: 0.9681 - val_loss: 0.0669
# Epoch 40/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 104ms/step - accuracy: 0.9712 - loss: 0.0434 - val_accuracy: 0.9717 - val_loss: 0.0650
#
# Fold 4 - Test Accuracy: 0.9862
# Weights saved to results(Normal_VS_All)\cnn_lstm_fold4.weights.h5
#
# ============================================================
# Fold 5/5
# ============================================================
# Original labels - Train: (array([0, 1, 2], dtype=int32), array([1280, 1280,  640]))
# Binary labels - Train: (array([0, 1]), array([1280, 1920]))
# Binary labels - Test: (array([0, 1]), array([320, 480]))
#
#  Data shapes:
#   Train: (5270, 868, 1)
#   Val:   (565, 868, 1)
#   Test:  (800, 868, 1)
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#  Class weights: {np.int64(0): np.float64(1.25), np.int64(1): np.float64(0.8333333333333334)}
#
#  Training Fold 5...
# Epoch 1/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 27s 107ms/step - accuracy: 0.7237 - loss: 0.3167 - val_accuracy: 0.6000 - val_loss: 0.4671
# Epoch 2/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 16s 99ms/step - accuracy: 0.8615 - loss: 0.2028 - val_accuracy: 0.7009 - val_loss: 0.3394
# Epoch 3/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 102ms/step - accuracy: 0.9074 - loss: 0.1485 - val_accuracy: 0.9133 - val_loss: 0.1347
# Epoch 4/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 101ms/step - accuracy: 0.9294 - loss: 0.1171 - val_accuracy: 0.9204 - val_loss: 0.1153
# Epoch 5/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 101ms/step - accuracy: 0.9440 - loss: 0.0961 - val_accuracy: 0.9115 - val_loss: 0.1253
# Epoch 6/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 101ms/step - accuracy: 0.9454 - loss: 0.0916 - val_accuracy: 0.9558 - val_loss: 0.0702
# Epoch 7/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 21s 127ms/step - accuracy: 0.9516 - loss: 0.0860 - val_accuracy: 0.9469 - val_loss: 0.0828
# Epoch 8/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 111ms/step - accuracy: 0.9526 - loss: 0.0831 - val_accuracy: 0.9469 - val_loss: 0.0831
# Epoch 9/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 105ms/step - accuracy: 0.9537 - loss: 0.0750 - val_accuracy: 0.9434 - val_loss: 0.0909
# Epoch 10/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 19s 115ms/step - accuracy: 0.9548 - loss: 0.0722 - val_accuracy: 0.9540 - val_loss: 0.0770
# Epoch 11/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 102ms/step - accuracy: 0.9545 - loss: 0.0714 - val_accuracy: 0.9575 - val_loss: 0.0720
# Epoch 12/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 102ms/step - accuracy: 0.9573 - loss: 0.0623 - val_accuracy: 0.9664 - val_loss: 0.0580
# Epoch 13/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 106ms/step - accuracy: 0.9594 - loss: 0.0636 - val_accuracy: 0.9735 - val_loss: 0.0461
# Epoch 14/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 106ms/step - accuracy: 0.9630 - loss: 0.0596 - val_accuracy: 0.9699 - val_loss: 0.0562
# Epoch 15/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 103ms/step - accuracy: 0.9615 - loss: 0.0576 - val_accuracy: 0.9717 - val_loss: 0.0561
# Epoch 16/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 101ms/step - accuracy: 0.9596 - loss: 0.0596 - val_accuracy: 0.9735 - val_loss: 0.0494
# Epoch 17/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 100ms/step - accuracy: 0.9660 - loss: 0.0513 - val_accuracy: 0.9717 - val_loss: 0.0453
# Epoch 18/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 16s 100ms/step - accuracy: 0.9693 - loss: 0.0481 - val_accuracy: 0.9788 - val_loss: 0.0369
# Epoch 19/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 103ms/step - accuracy: 0.9683 - loss: 0.0464 - val_accuracy: 0.9805 - val_loss: 0.0464
# Epoch 20/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 102ms/step - accuracy: 0.9655 - loss: 0.0521 - val_accuracy: 0.9805 - val_loss: 0.0327
# Epoch 21/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 103ms/step - accuracy: 0.9687 - loss: 0.0427 - val_accuracy: 0.9752 - val_loss: 0.0519
# Epoch 22/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 100ms/step - accuracy: 0.9691 - loss: 0.0451 - val_accuracy: 0.9788 - val_loss: 0.0366
# Epoch 23/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 105ms/step - accuracy: 0.9708 - loss: 0.0427 - val_accuracy: 0.9664 - val_loss: 0.0659
# Epoch 24/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 111ms/step - accuracy: 0.9740 - loss: 0.0398 - val_accuracy: 0.9575 - val_loss: 0.0653
# Epoch 25/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 104ms/step - accuracy: 0.9672 - loss: 0.0442 - val_accuracy: 0.9681 - val_loss: 0.0671
# Epoch 26/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 111ms/step - accuracy: 0.9713 - loss: 0.0431 - val_accuracy: 0.9593 - val_loss: 0.0949
# Epoch 27/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9725 - loss: 0.0419 - val_accuracy: 0.9699 - val_loss: 0.0564
# Epoch 28/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 103ms/step - accuracy: 0.9736 - loss: 0.0360 - val_accuracy: 0.9451 - val_loss: 0.1070
# Epoch 29/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 107ms/step - accuracy: 0.9763 - loss: 0.0368 - val_accuracy: 0.9735 - val_loss: 0.0715
# Epoch 30/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 106ms/step - accuracy: 0.9725 - loss: 0.0379 - val_accuracy: 0.9717 - val_loss: 0.0735
# Epoch 31/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 106ms/step - accuracy: 0.9750 - loss: 0.0352 - val_accuracy: 0.9628 - val_loss: 0.0917
# Epoch 32/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 103ms/step - accuracy: 0.9740 - loss: 0.0347 - val_accuracy: 0.9575 - val_loss: 0.1041
# Epoch 33/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 105ms/step - accuracy: 0.9742 - loss: 0.0365 - val_accuracy: 0.9681 - val_loss: 0.0810
# Epoch 34/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 106ms/step - accuracy: 0.9774 - loss: 0.0314 - val_accuracy: 0.9628 - val_loss: 0.0666
# Epoch 35/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 107ms/step - accuracy: 0.9782 - loss: 0.0333 - val_accuracy: 0.9611 - val_loss: 0.1010
# Epoch 36/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 105ms/step - accuracy: 0.9797 - loss: 0.0293 - val_accuracy: 0.9593 - val_loss: 0.1233
# Epoch 37/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 107ms/step - accuracy: 0.9812 - loss: 0.0310 - val_accuracy: 0.9558 - val_loss: 0.1105
# Epoch 38/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 107ms/step - accuracy: 0.9808 - loss: 0.0289 - val_accuracy: 0.9593 - val_loss: 0.1146
# Epoch 39/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 107ms/step - accuracy: 0.9793 - loss: 0.0288 - val_accuracy: 0.9611 - val_loss: 0.1062
# Epoch 40/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 106ms/step - accuracy: 0.9825 - loss: 0.0254 - val_accuracy: 0.9611 - val_loss: 0.1153
#
# Fold 5 - Test Accuracy: 0.9137
# Weights saved to results(Normal_VS_All)\cnn_lstm_fold5.weights.h5
#
# ============================================================
# FINAL RESULTS
# ============================================================
# Mean Accuracy across all folds: 0.9540 ± 0.0264
# Accuracy per fold: ['0.9550', '0.9375', '0.9775', '0.9862', '0.9137']
#  Overall Metrics (All Folds Combined):
#   Accuracy : 0.9540
#   Precision: 0.9443
#   Recall   : 0.9812
#   F1-score : 0.9624
#
#  CNN+LSTM Training Completed!

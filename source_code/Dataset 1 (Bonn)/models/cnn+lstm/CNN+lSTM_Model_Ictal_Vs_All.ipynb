# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv1D, MaxPooling1D, LSTM, Dense, Dropout, BatchNormalization
)
from tensorflow.keras.optimizers import Adam

PREPROCESSING_DIR = r"Preprocessing_Updated_Kfold"  
N_FOLDS = 5
RESULTS_DIR = "results(Ictal)"

os.makedirs(RESULTS_DIR, exist_ok=True)

def hybrid_focal_loss(alpha=0.25, gamma=2.0, bce_weight=0.5):
   
    def loss(y_true, y_pred):
        bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)

        y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
        focal = -alpha * (1 - y_pred) ** gamma * y_true * K.log(y_pred) \
                - (1 - alpha) * y_pred ** gamma * (1 - y_true) * K.log(1 - y_pred)

        focal = K.mean(focal, axis=-1)

        return bce_weight * bce + (1 - bce_weight) * focal

    return loss

def build_cnn_lstm(input_length):
    model = Sequential([
        Conv1D(32, kernel_size=7, activation='relu', input_shape=(input_length, 1)),
        BatchNormalization(),
        MaxPooling1D(2),
        Dropout(0.2),

        Conv1D(64, kernel_size=5, activation='relu'),
        BatchNormalization(),
        MaxPooling1D(2),
        Dropout(0.3),

        Conv1D(128, kernel_size=3, activation='relu'),
        BatchNormalization(),
        MaxPooling1D(2),
        Dropout(0.4),
        
        LSTM(64, return_sequences=False),

        Dense(64, activation='relu'),
        Dropout(0.4),

        Dense(1, activation='sigmoid')
    ])

    model.compile(
        optimizer=Adam(1e-4),
        loss=hybrid_focal_loss(alpha=0.25, gamma=2.0, bce_weight=0.5),
        metrics=['accuracy']
    )
    return model

def augment_signal(signal):
    noise = np.random.normal(0, 0.005, signal.shape)
    signal_noisy = signal + noise

    shift = np.random.randint(-5, 5)
    signal_shifted = np.roll(signal_noisy, shift)

    scale = np.random.uniform(0.97, 1.03)
    signal_scaled = signal_shifted * scale

    return signal_scaled

def augment_batch(X, y):
    X_aug = []
    y_aug = []

    for i in range(len(X)):
        X_aug.append(X[i])
        y_aug.append(y[i])

        X_aug.append(augment_signal(X[i]))
        y_aug.append(y[i])

    return np.array(X_aug), np.array(y_aug)

acc_per_fold = []
conf_matrices = []

for fold_no in range(N_FOLDS):
    print(f"\n{'='*60}")
    print(f"Fold {fold_no + 1}/{N_FOLDS}")
    print(f"{'='*60}")

    X_train_full = np.load(os.path.join(PREPROCESSING_DIR, f"fold_{fold_no}_X_train.npy"), allow_pickle=True)
    y_train_full = np.load(os.path.join(PREPROCESSING_DIR, f"fold_{fold_no}_y_train.npy"), allow_pickle=True)
    X_test = np.load(os.path.join(PREPROCESSING_DIR, f"fold_{fold_no}_X_test.npy"), allow_pickle=True)
    y_test = np.load(os.path.join(PREPROCESSING_DIR, f"fold_{fold_no}_y_test.npy"), allow_pickle=True)
    
    if X_train_full.dtype == object:
        X_train_full = np.vstack(X_train_full).astype(np.float32)
    if X_test.dtype == object:
        X_test = np.vstack(X_test).astype(np.float32)
    
    X_train_full = X_train_full.astype(np.float32)
    X_test = X_test.astype(np.float32)
    y_train_full = y_train_full.astype(np.int32)
    y_test = y_test.astype(np.int32)

   
    y_train_full_binary = np.where(y_train_full == 2, 0, 1)
    y_test_binary = np.where(y_test == 2, 0, 1)

    print(f"Original labels - Train: {np.unique(y_train_full, return_counts=True)}")
    print(f"Binary labels - Train: {np.unique(y_train_full_binary, return_counts=True)}")
    print(f"Binary labels - Test: {np.unique(y_test_binary, return_counts=True)}")

    X_train, X_val, y_train, y_val = train_test_split(
        X_train_full, y_train_full_binary, 
        test_size=0.1765, 
        stratify=y_train_full_binary, 
        random_state=42
    )

    X_train, y_train = augment_batch(X_train, y_train)

    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

    print(f"\n Data shapes:")
    print(f"  Train: {X_train.shape}")
    print(f"  Val:   {X_val.shape}")
    print(f"  Test:  {X_test.shape}")

    model = build_cnn_lstm(X_train.shape[1])
    
    if fold_no == 0:  
        model.summary()

    cw = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
    class_weights = {0: cw[0], 1: cw[1]}
    print(f"\n zClass weights: {class_weights}")

    print(f"\n Training Fold {fold_no + 1}...")
    history = model.fit(
        X_train, y_train,
        epochs=40,
        batch_size=32,
        validation_data=(X_val, y_val),
        class_weight=class_weights,
        verbose=1
    )

    test_loss, test_acc = model.evaluate(X_test, y_test_binary, verbose=0)
    acc_per_fold.append(test_acc)
    print(f"\n Fold {fold_no + 1} - Test Accuracy: {test_acc:.4f}")

    weight_path = os.path.join(RESULTS_DIR, f"cnn_lstm_fold{fold_no + 1}.weights.h5")
    model.save_weights(weight_path)
    print(f" Weights saved to {weight_path}")

    y_pred = (model.predict(X_test, verbose=0) > 0.5).astype("int32").flatten()
    cm = confusion_matrix(y_test_binary, y_pred)
    conf_matrices.append(cm)

    plt.figure(figsize=(6, 5))
    sns.heatmap(
        cm, annot=True, fmt='d', cmap='Blues',
        xticklabels=['ICTAL', 'NON-ICTAL'], 
        yticklabels=['ICTAL', 'NON-ICTAL']
    )
    plt.title(f"Fold {fold_no + 1} Confusion Matrix\nAccuracy: {test_acc:.4f}")
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.savefig(os.path.join(RESULTS_DIR, f"cnn_lstm_conf_fold{fold_no + 1}.png"))
    plt.close()

print("\n" + "="*60)
print(" FINAL RESULTS")
print("="*60)
print(f"Mean Accuracy across all folds: {np.mean(acc_per_fold):.4f} =+ {np.std(acc_per_fold):.4f}")
print(f"Accuracy per fold: {[f'{acc:.4f}' for acc in acc_per_fold]}")

total_cm = np.sum(conf_matrices, axis=0)

plt.figure(figsize=(6, 5))
sns.heatmap(
    total_cm, annot=True, fmt='d', cmap='Greens',
    xticklabels=['ICTAL', 'NON-ICTAL'], 
    yticklabels=['ICTAL', 'NON-ICTAL']
)
plt.title("Overall Confusion Matrix (All Folds)")
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "cnn_lstm_conf_overall.png"))
plt.show()

tn, fp, fn, tp = total_cm.ravel()

overall_accuracy = (tp + tn) / np.sum(total_cm)
overall_precision = tp / (tp + fp) if (tp + fp) > 0 else 0
overall_recall = tp / (tp + fn) if (tp + fn) > 0 else 0
overall_f1 = 2 * overall_precision * overall_recall / (overall_precision + overall_recall) if (overall_precision + overall_recall) > 0 else 0

print("\n Overall Metrics (All Folds Combined):")
print(f"  Accuracy : {overall_accuracy:.4f}")
print(f"  Precision: {overall_precision:.4f}")
print(f"  Recall   : {overall_recall:.4f}")
print(f"  F1-score : {overall_f1:.4f}")

print("\n CNN+LSTM Training Completed!")
# Out:
# ============================================================
#  Fold 1/5
# ============================================================
# Original labels - Train: (array([0, 1, 2], dtype=int32), array([1280, 1280,  640]))
# Binary labels - Train: (array([0, 1]), array([ 640, 2560]))
# Binary labels - Test: (array([0, 1]), array([160, 640]))
#
#  Data shapes:
#   Train: (5270, 868, 1)
#   Val:   (565, 868, 1)
#   Test:  (800, 868, 1)
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_3 (Conv1D)               │ (None, 862, 32)        │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 862, 32)        │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 431, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 431, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 427, 64)        │        10,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 427, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 213, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 213, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 211, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 211, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_5 (MaxPooling1D)  │ (None, 105, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 105, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 89,793 (350.75 KB)
#  Trainable params: 89,345 (349.00 KB)
#  Non-trainable params: 448 (1.75 KB)
#  zClass weights: {0: np.float64(2.5), 1: np.float64(0.625)}
#
#  Training Fold 1...
# Epoch 1/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 12s 57ms/step - accuracy: 0.5108 - loss: 0.3915 - val_accuracy: 0.8000 - val_loss: 0.3381
# Epoch 2/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - accuracy: 0.5245 - loss: 0.3653 - val_accuracy: 0.7858 - val_loss: 0.3249
# Epoch 3/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - accuracy: 0.5979 - loss: 0.3349 - val_accuracy: 0.8142 - val_loss: 0.2900
# Epoch 4/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - accuracy: 0.7224 - loss: 0.2755 - val_accuracy: 0.8566 - val_loss: 0.2339
# Epoch 5/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - accuracy: 0.8867 - loss: 0.1684 - val_accuracy: 0.9009 - val_loss: 0.1816
# Epoch 6/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - accuracy: 0.9586 - loss: 0.0885 - val_accuracy: 0.9097 - val_loss: 0.1922
# Epoch 7/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - accuracy: 0.9729 - loss: 0.0686 - val_accuracy: 0.9204 - val_loss: 0.1740
# Epoch 8/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.9776 - loss: 0.0632 - val_accuracy: 0.9469 - val_loss: 0.1248
# Epoch 9/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - accuracy: 0.9761 - loss: 0.0630 - val_accuracy: 0.9310 - val_loss: 0.1466
# Epoch 10/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - accuracy: 0.9734 - loss: 0.0570 - val_accuracy: 0.9363 - val_loss: 0.1297
# Epoch 11/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.9770 - loss: 0.0464 - val_accuracy: 0.9221 - val_loss: 0.1884
# Epoch 12/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.9786 - loss: 0.0423 - val_accuracy: 0.9239 - val_loss: 0.1639
# Epoch 13/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.9843 - loss: 0.0383 - val_accuracy: 0.9434 - val_loss: 0.1444
# Epoch 14/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - accuracy: 0.9824 - loss: 0.0390 - val_accuracy: 0.9504 - val_loss: 0.1228
# Epoch 15/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 0.9822 - loss: 0.0365 - val_accuracy: 0.9575 - val_loss: 0.1234
# Epoch 16/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - accuracy: 0.9748 - loss: 0.0412 - val_accuracy: 0.9434 - val_loss: 0.1304
# Epoch 17/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.9899 - loss: 0.0255 - val_accuracy: 0.9398 - val_loss: 0.1729
# Epoch 18/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - accuracy: 0.9814 - loss: 0.0311 - val_accuracy: 0.9363 - val_loss: 0.1897
# Epoch 19/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.9863 - loss: 0.0268 - val_accuracy: 0.9381 - val_loss: 0.1745
# Epoch 20/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - accuracy: 0.9841 - loss: 0.0325 - val_accuracy: 0.9540 - val_loss: 0.1386
# Epoch 21/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - accuracy: 0.9920 - loss: 0.0189 - val_accuracy: 0.9558 - val_loss: 0.1405
# Epoch 22/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - accuracy: 0.9918 - loss: 0.0184 - val_accuracy: 0.9504 - val_loss: 0.1663
# Epoch 23/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - accuracy: 0.9918 - loss: 0.0200 - val_accuracy: 0.9646 - val_loss: 0.1094
# Epoch 24/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.9901 - loss: 0.0250 - val_accuracy: 0.9540 - val_loss: 0.1434
# Epoch 25/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - accuracy: 0.9924 - loss: 0.0146 - val_accuracy: 0.9469 - val_loss: 0.1675
# Epoch 26/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - accuracy: 0.9884 - loss: 0.0235 - val_accuracy: 0.9451 - val_loss: 0.1631
# Epoch 27/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 0.9858 - loss: 0.0242 - val_accuracy: 0.9522 - val_loss: 0.1560
# Epoch 28/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - accuracy: 0.9880 - loss: 0.0232 - val_accuracy: 0.9487 - val_loss: 0.1621
# Epoch 29/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 0.9926 - loss: 0.0157 - val_accuracy: 0.9540 - val_loss: 0.1522
# Epoch 30/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - accuracy: 0.9913 - loss: 0.0203 - val_accuracy: 0.9522 - val_loss: 0.1528
# Epoch 31/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - accuracy: 0.9915 - loss: 0.0173 - val_accuracy: 0.9504 - val_loss: 0.1827
# Epoch 32/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - accuracy: 0.9926 - loss: 0.0137 - val_accuracy: 0.9469 - val_loss: 0.1742
# Epoch 33/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - accuracy: 0.9960 - loss: 0.0138 - val_accuracy: 0.9558 - val_loss: 0.1501
# Epoch 34/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - accuracy: 0.9934 - loss: 0.0176 - val_accuracy: 0.9593 - val_loss: 0.1433
# Epoch 35/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - accuracy: 0.9894 - loss: 0.0202 - val_accuracy: 0.9593 - val_loss: 0.1238
# Epoch 36/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - accuracy: 0.9898 - loss: 0.0209 - val_accuracy: 0.9646 - val_loss: 0.1212
# Epoch 37/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - accuracy: 0.9879 - loss: 0.0186 - val_accuracy: 0.9575 - val_loss: 0.1659
# Epoch 38/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - accuracy: 0.9935 - loss: 0.0126 - val_accuracy: 0.9611 - val_loss: 0.1466
# Epoch 39/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - accuracy: 0.9913 - loss: 0.0142 - val_accuracy: 0.9664 - val_loss: 0.1359
# Epoch 40/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - accuracy: 0.9945 - loss: 0.0106 - val_accuracy: 0.9664 - val_loss: 0.1346
#
#  Fold 1 - Test Accuracy: 0.9638
#  Weights saved to results(Ictal)\cnn_lstm_fold1.weights.h5
#
# ============================================================
#  Fold 2/5
# ============================================================
# Original labels - Train: (array([0, 1, 2], dtype=int32), array([1280, 1280,  640]))
# Binary labels - Train: (array([0, 1]), array([ 640, 2560]))
# Binary labels - Test: (array([0, 1]), array([160, 640]))
#
#  Data shapes:
#   Train: (5270, 868, 1)
#   Val:   (565, 868, 1)
#   Test:  (800, 868, 1)
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#  zClass weights: {0: np.float64(2.5), 1: np.float64(0.625)}
#
#  Training Fold 2...
# Epoch 1/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 11s 49ms/step - accuracy: 0.5051 - loss: 0.3882 - val_accuracy: 0.8000 - val_loss: 0.3450
# Epoch 2/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - accuracy: 0.4837 - loss: 0.3674 - val_accuracy: 0.7947 - val_loss: 0.3399
# Epoch 3/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - accuracy: 0.5954 - loss: 0.3376 - val_accuracy: 0.8549 - val_loss: 0.2924
# Epoch 4/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - accuracy: 0.7228 - loss: 0.2831 - val_accuracy: 0.9062 - val_loss: 0.2115
# Epoch 5/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 0.8994 - loss: 0.1598 - val_accuracy: 0.9593 - val_loss: 0.1099
# Epoch 6/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - accuracy: 0.9708 - loss: 0.0879 - val_accuracy: 0.9628 - val_loss: 0.0893
# Epoch 7/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - accuracy: 0.9674 - loss: 0.0745 - val_accuracy: 0.9487 - val_loss: 0.0922
# Epoch 8/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - accuracy: 0.9694 - loss: 0.0714 - val_accuracy: 0.9646 - val_loss: 0.0800
# Epoch 9/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.9746 - loss: 0.0555 - val_accuracy: 0.9593 - val_loss: 0.0849
# Epoch 10/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - accuracy: 0.9805 - loss: 0.0552 - val_accuracy: 0.9575 - val_loss: 0.0802
# Epoch 11/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.9789 - loss: 0.0531 - val_accuracy: 0.9735 - val_loss: 0.0629
# Epoch 12/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 16s 95ms/step - accuracy: 0.9660 - loss: 0.0611 - val_accuracy: 0.9469 - val_loss: 0.1051
# Epoch 13/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 16s 98ms/step - accuracy: 0.9791 - loss: 0.0506 - val_accuracy: 0.9487 - val_loss: 0.0987
# Epoch 14/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 16s 96ms/step - accuracy: 0.9609 - loss: 0.0683 - val_accuracy: 0.9699 - val_loss: 0.0590
# Epoch 15/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 16s 97ms/step - accuracy: 0.9871 - loss: 0.0362 - val_accuracy: 0.9593 - val_loss: 0.0901
# Epoch 16/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 16s 94ms/step - accuracy: 0.9820 - loss: 0.0367 - val_accuracy: 0.9558 - val_loss: 0.1046
# Epoch 17/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 90ms/step - accuracy: 0.9837 - loss: 0.0355 - val_accuracy: 0.9646 - val_loss: 0.0878
# Epoch 18/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 90ms/step - accuracy: 0.9806 - loss: 0.0409 - val_accuracy: 0.9611 - val_loss: 0.0791
# Epoch 19/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 16s 98ms/step - accuracy: 0.9888 - loss: 0.0292 - val_accuracy: 0.9611 - val_loss: 0.0888
# Epoch 20/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 92ms/step - accuracy: 0.9854 - loss: 0.0303 - val_accuracy: 0.9646 - val_loss: 0.0889
# Epoch 21/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 88ms/step - accuracy: 0.9829 - loss: 0.0282 - val_accuracy: 0.9646 - val_loss: 0.0923
# Epoch 22/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 13s 81ms/step - accuracy: 0.9888 - loss: 0.0250 - val_accuracy: 0.9646 - val_loss: 0.0880
# Epoch 23/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 13s 82ms/step - accuracy: 0.9920 - loss: 0.0182 - val_accuracy: 0.9575 - val_loss: 0.1024
# Epoch 24/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 16s 94ms/step - accuracy: 0.9898 - loss: 0.0280 - val_accuracy: 0.9664 - val_loss: 0.0911
# Epoch 25/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 14s 83ms/step - accuracy: 0.9911 - loss: 0.0222 - val_accuracy: 0.9575 - val_loss: 0.1053
# Epoch 26/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 105ms/step - accuracy: 0.9907 - loss: 0.0226 - val_accuracy: 0.9699 - val_loss: 0.0691
# Epoch 27/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 16s 98ms/step - accuracy: 0.9898 - loss: 0.0230 - val_accuracy: 0.9699 - val_loss: 0.0679
# Epoch 28/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 91ms/step - accuracy: 0.9898 - loss: 0.0199 - val_accuracy: 0.9611 - val_loss: 0.0905
# Epoch 29/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 14s 87ms/step - accuracy: 0.9873 - loss: 0.0224 - val_accuracy: 0.9628 - val_loss: 0.1096
# Epoch 30/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 92ms/step - accuracy: 0.9911 - loss: 0.0157 - val_accuracy: 0.9788 - val_loss: 0.0562
# Epoch 31/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 148ms/step - accuracy: 0.9911 - loss: 0.0156 - val_accuracy: 0.9717 - val_loss: 0.0708
# Epoch 32/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 147ms/step - accuracy: 0.9871 - loss: 0.0220 - val_accuracy: 0.9646 - val_loss: 0.1280
# Epoch 33/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 90ms/step - accuracy: 0.9922 - loss: 0.0150 - val_accuracy: 0.9646 - val_loss: 0.1017
# Epoch 34/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 14s 86ms/step - accuracy: 0.9913 - loss: 0.0194 - val_accuracy: 0.9699 - val_loss: 0.0968
# Epoch 35/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 133ms/step - accuracy: 0.9926 - loss: 0.0130 - val_accuracy: 0.9788 - val_loss: 0.0630
# Epoch 36/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 142ms/step - accuracy: 0.9915 - loss: 0.0163 - val_accuracy: 0.9805 - val_loss: 0.0548
# Epoch 37/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 140ms/step - accuracy: 0.9915 - loss: 0.0134 - val_accuracy: 0.9681 - val_loss: 0.0987
# Epoch 38/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 136ms/step - accuracy: 0.9945 - loss: 0.0107 - val_accuracy: 0.9646 - val_loss: 0.1198
# Epoch 39/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 141ms/step - accuracy: 0.9954 - loss: 0.0097 - val_accuracy: 0.9788 - val_loss: 0.0694
# Epoch 40/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 141ms/step - accuracy: 0.9941 - loss: 0.0121 - val_accuracy: 0.9646 - val_loss: 0.1135
#
#  Fold 2 - Test Accuracy: 0.9663
#  Weights saved to results(Ictal)\cnn_lstm_fold2.weights.h5
#
# ============================================================
#  Fold 3/5
# ============================================================
# Original labels - Train: (array([0, 1, 2], dtype=int32), array([1280, 1280,  640]))
# Binary labels - Train: (array([0, 1]), array([ 640, 2560]))
# Binary labels - Test: (array([0, 1]), array([160, 640]))
#
#  Data shapes:
#   Train: (5270, 868, 1)
#   Val:   (565, 868, 1)
#   Test:  (800, 868, 1)
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#  zClass weights: {0: np.float64(2.5), 1: np.float64(0.625)}
#
#  Training Fold 3...
# Epoch 1/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 73s 178ms/step - accuracy: 0.5326 - loss: 0.3918 - val_accuracy: 0.7982 - val_loss: 0.3392
# Epoch 2/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 144ms/step - accuracy: 0.4738 - loss: 0.3759 - val_accuracy: 0.7788 - val_loss: 0.3283
# Epoch 3/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - accuracy: 0.5712 - loss: 0.3483 - val_accuracy: 0.7912 - val_loss: 0.2950
# Epoch 4/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 143ms/step - accuracy: 0.6930 - loss: 0.2975 - val_accuracy: 0.8832 - val_loss: 0.2102
# Epoch 5/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 142ms/step - accuracy: 0.8729 - loss: 0.1882 - val_accuracy: 0.9593 - val_loss: 0.1027
# Epoch 6/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 143ms/step - accuracy: 0.9581 - loss: 0.1039 - val_accuracy: 0.9593 - val_loss: 0.1048
# Epoch 7/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 133ms/step - accuracy: 0.9677 - loss: 0.0815 - val_accuracy: 0.9575 - val_loss: 0.1002
# Epoch 8/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 109ms/step - accuracy: 0.9664 - loss: 0.0747 - val_accuracy: 0.9327 - val_loss: 0.1332
# Epoch 9/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 108ms/step - accuracy: 0.9742 - loss: 0.0609 - val_accuracy: 0.9504 - val_loss: 0.1039
# Epoch 10/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 19s 116ms/step - accuracy: 0.9746 - loss: 0.0531 - val_accuracy: 0.9522 - val_loss: 0.1054
# Epoch 11/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 134ms/step - accuracy: 0.9805 - loss: 0.0462 - val_accuracy: 0.9611 - val_loss: 0.0815
# Epoch 12/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 142ms/step - accuracy: 0.9797 - loss: 0.0457 - val_accuracy: 0.9735 - val_loss: 0.0624
# Epoch 13/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 139ms/step - accuracy: 0.9787 - loss: 0.0419 - val_accuracy: 0.9451 - val_loss: 0.1259
# Epoch 14/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 140ms/step - accuracy: 0.9850 - loss: 0.0372 - val_accuracy: 0.9646 - val_loss: 0.0907
# Epoch 15/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 108ms/step - accuracy: 0.9748 - loss: 0.0483 - val_accuracy: 0.9611 - val_loss: 0.0889
# Epoch 16/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 144ms/step - accuracy: 0.9856 - loss: 0.0340 - val_accuracy: 0.9575 - val_loss: 0.1066
# Epoch 17/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 141ms/step - accuracy: 0.9818 - loss: 0.0365 - val_accuracy: 0.9628 - val_loss: 0.0967
# Epoch 18/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 139ms/step - accuracy: 0.9829 - loss: 0.0337 - val_accuracy: 0.9628 - val_loss: 0.1028
# Epoch 19/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 143ms/step - accuracy: 0.9829 - loss: 0.0327 - val_accuracy: 0.9646 - val_loss: 0.0918
# Epoch 20/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 139ms/step - accuracy: 0.9875 - loss: 0.0284 - val_accuracy: 0.9788 - val_loss: 0.0542
# Epoch 21/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - accuracy: 0.9884 - loss: 0.0233 - val_accuracy: 0.9788 - val_loss: 0.0569
# Epoch 22/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 19s 114ms/step - accuracy: 0.9875 - loss: 0.0250 - val_accuracy: 0.9752 - val_loss: 0.0537
# Epoch 23/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 133ms/step - accuracy: 0.9892 - loss: 0.0209 - val_accuracy: 0.9699 - val_loss: 0.0729
# Epoch 24/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 136ms/step - accuracy: 0.9896 - loss: 0.0262 - val_accuracy: 0.9664 - val_loss: 0.0928
# Epoch 25/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 109ms/step - accuracy: 0.9913 - loss: 0.0233 - val_accuracy: 0.9699 - val_loss: 0.0767
# Epoch 26/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 21s 130ms/step - accuracy: 0.9903 - loss: 0.0234 - val_accuracy: 0.9735 - val_loss: 0.0704
# Epoch 27/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 19s 112ms/step - accuracy: 0.9877 - loss: 0.0230 - val_accuracy: 0.9805 - val_loss: 0.0514
# Epoch 28/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 132ms/step - accuracy: 0.9928 - loss: 0.0144 - val_accuracy: 0.9770 - val_loss: 0.0524
# Epoch 29/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - accuracy: 0.9907 - loss: 0.0265 - val_accuracy: 0.9699 - val_loss: 0.0722
# Epoch 30/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 139ms/step - accuracy: 0.9858 - loss: 0.0247 - val_accuracy: 0.9805 - val_loss: 0.0523
# Epoch 31/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 140ms/step - accuracy: 0.9939 - loss: 0.0145 - val_accuracy: 0.9770 - val_loss: 0.0656
# Epoch 32/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 137ms/step - accuracy: 0.9949 - loss: 0.0146 - val_accuracy: 0.9912 - val_loss: 0.0267
# Epoch 33/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 143ms/step - accuracy: 0.9926 - loss: 0.0146 - val_accuracy: 0.9788 - val_loss: 0.0388
# Epoch 34/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 27s 164ms/step - accuracy: 0.9909 - loss: 0.0181 - val_accuracy: 0.9876 - val_loss: 0.0159
# Epoch 35/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 37s 137ms/step - accuracy: 0.9911 - loss: 0.0181 - val_accuracy: 0.9770 - val_loss: 0.0515
# Epoch 36/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - accuracy: 0.9934 - loss: 0.0149 - val_accuracy: 0.9788 - val_loss: 0.0416
# Epoch 37/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - accuracy: 0.9899 - loss: 0.0231 - val_accuracy: 0.9841 - val_loss: 0.0469
# Epoch 38/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 20s 122ms/step - accuracy: 0.9856 - loss: 0.0242 - val_accuracy: 0.9858 - val_loss: 0.0325
# Epoch 39/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 90ms/step - accuracy: 0.9935 - loss: 0.0176 - val_accuracy: 0.9770 - val_loss: 0.0599
# Epoch 40/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 14s 84ms/step - accuracy: 0.9951 - loss: 0.0116 - val_accuracy: 0.9894 - val_loss: 0.0198
#
#  Fold 3 - Test Accuracy: 0.9837
#  Weights saved to results(Ictal)\cnn_lstm_fold3.weights.h5
#
# ============================================================
#  Fold 4/5
# ============================================================
# Original labels - Train: (array([0, 1, 2], dtype=int32), array([1280, 1280,  640]))
# Binary labels - Train: (array([0, 1]), array([ 640, 2560]))
# Binary labels - Test: (array([0, 1]), array([160, 640]))
#
#  Data shapes:
#   Train: (5270, 868, 1)
#   Val:   (565, 868, 1)
#   Test:  (800, 868, 1)
#
#  zClass weights: {0: np.float64(2.5), 1: np.float64(0.625)}
#
#  Training Fold 4...
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 38s 195ms/step - accuracy: 0.5953 - loss: 0.3900 - val_accuracy: 0.8000 - val_loss: 0.3591
# Epoch 2/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 33s 147ms/step - accuracy: 0.5148 - loss: 0.3666 - val_accuracy: 0.7912 - val_loss: 0.3363
# Epoch 3/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 150ms/step - accuracy: 0.6319 - loss: 0.3249 - val_accuracy: 0.8531 - val_loss: 0.2838
# Epoch 4/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 152ms/step - accuracy: 0.8047 - loss: 0.2311 - val_accuracy: 0.9168 - val_loss: 0.1774
# Epoch 5/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 149ms/step - accuracy: 0.9594 - loss: 0.0960 - val_accuracy: 0.9327 - val_loss: 0.1357
# Epoch 6/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 151ms/step - accuracy: 0.9712 - loss: 0.0704 - val_accuracy: 0.9522 - val_loss: 0.1029
# Epoch 7/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 147ms/step - accuracy: 0.9776 - loss: 0.0569 - val_accuracy: 0.9469 - val_loss: 0.1079
# Epoch 8/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 93ms/step - accuracy: 0.9784 - loss: 0.0492 - val_accuracy: 0.9416 - val_loss: 0.1277
# Epoch 9/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 13s 81ms/step - accuracy: 0.9799 - loss: 0.0454 - val_accuracy: 0.9416 - val_loss: 0.1324
# Epoch 10/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 11s 66ms/step - accuracy: 0.9856 - loss: 0.0362 - val_accuracy: 0.9310 - val_loss: 0.1640
# Epoch 11/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 134ms/step - accuracy: 0.9776 - loss: 0.0420 - val_accuracy: 0.9381 - val_loss: 0.1636
# Epoch 12/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 152ms/step - accuracy: 0.9835 - loss: 0.0343 - val_accuracy: 0.9558 - val_loss: 0.1189
# Epoch 13/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 153ms/step - accuracy: 0.9901 - loss: 0.0209 - val_accuracy: 0.9487 - val_loss: 0.1335
# Epoch 14/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 148ms/step - accuracy: 0.9861 - loss: 0.0264 - val_accuracy: 0.9434 - val_loss: 0.1696
# Epoch 15/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 140ms/step - accuracy: 0.9920 - loss: 0.0217 - val_accuracy: 0.9434 - val_loss: 0.1599
# Epoch 16/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 28s 167ms/step - accuracy: 0.9863 - loss: 0.0259 - val_accuracy: 0.9469 - val_loss: 0.1802
# Epoch 17/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 29s 172ms/step - accuracy: 0.9901 - loss: 0.0214 - val_accuracy: 0.9327 - val_loss: 0.2080
# Epoch 18/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 167ms/step - accuracy: 0.9915 - loss: 0.0178 - val_accuracy: 0.9416 - val_loss: 0.1834
# Epoch 19/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 148ms/step - accuracy: 0.9882 - loss: 0.0216 - val_accuracy: 0.9381 - val_loss: 0.2286
# Epoch 20/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 40s 139ms/step - accuracy: 0.9890 - loss: 0.0187 - val_accuracy: 0.9398 - val_loss: 0.2042
# Epoch 21/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 103ms/step - accuracy: 0.9899 - loss: 0.0189 - val_accuracy: 0.9575 - val_loss: 0.1572
# Epoch 22/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 16s 99ms/step - accuracy: 0.9937 - loss: 0.0157 - val_accuracy: 0.9469 - val_loss: 0.2105
# Epoch 23/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 15s 91ms/step - accuracy: 0.9879 - loss: 0.0200 - val_accuracy: 0.9593 - val_loss: 0.1369
# Epoch 24/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 143ms/step - accuracy: 0.9932 - loss: 0.0138 - val_accuracy: 0.9416 - val_loss: 0.2219
# Epoch 25/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 147ms/step - accuracy: 0.9924 - loss: 0.0132 - val_accuracy: 0.9540 - val_loss: 0.1788
# Epoch 26/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 21s 125ms/step - accuracy: 0.9856 - loss: 0.0220 - val_accuracy: 0.9593 - val_loss: 0.1539
# Epoch 27/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 142ms/step - accuracy: 0.9943 - loss: 0.0119 - val_accuracy: 0.9504 - val_loss: 0.2201
# Epoch 28/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 19s 113ms/step - accuracy: 0.9928 - loss: 0.0125 - val_accuracy: 0.9628 - val_loss: 0.1458
# Epoch 29/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 143ms/step - accuracy: 0.9951 - loss: 0.0099 - val_accuracy: 0.9504 - val_loss: 0.1900
# Epoch 30/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 144ms/step - accuracy: 0.9930 - loss: 0.0127 - val_accuracy: 0.9628 - val_loss: 0.1601
# Epoch 31/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 150ms/step - accuracy: 0.9947 - loss: 0.0126 - val_accuracy: 0.9540 - val_loss: 0.1595
# Epoch 32/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 145ms/step - accuracy: 0.9949 - loss: 0.0144 - val_accuracy: 0.9646 - val_loss: 0.1416
# Epoch 33/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 149ms/step - accuracy: 0.9905 - loss: 0.0149 - val_accuracy: 0.9664 - val_loss: 0.1274
# Epoch 34/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 21s 129ms/step - accuracy: 0.9943 - loss: 0.0098 - val_accuracy: 0.9558 - val_loss: 0.1896
# Epoch 35/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 21s 125ms/step - accuracy: 0.9947 - loss: 0.0097 - val_accuracy: 0.9611 - val_loss: 0.1602
# Epoch 36/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 21s 126ms/step - accuracy: 0.9951 - loss: 0.0084 - val_accuracy: 0.9558 - val_loss: 0.2328
# Epoch 37/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 14s 86ms/step - accuracy: 0.9945 - loss: 0.0148 - val_accuracy: 0.9575 - val_loss: 0.1924
# Epoch 38/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 14s 86ms/step - accuracy: 0.9947 - loss: 0.0103 - val_accuracy: 0.9752 - val_loss: 0.1006
# Epoch 39/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 20s 120ms/step - accuracy: 0.9968 - loss: 0.0068 - val_accuracy: 0.9540 - val_loss: 0.2105
# Epoch 40/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 147ms/step - accuracy: 0.9854 - loss: 0.0231 - val_accuracy: 0.9681 - val_loss: 0.1096
#
#  Fold 4 - Test Accuracy: 0.9588
#  Weights saved to results(Ictal)\cnn_lstm_fold4.weights.h5
#
# ============================================================
#  Fold 5/5
# ============================================================
# Original labels - Train: (array([0, 1, 2], dtype=int32), array([1280, 1280,  640]))
# Binary labels - Train: (array([0, 1]), array([ 640, 2560]))
# Binary labels - Test: (array([0, 1]), array([160, 640]))
#
#  Data shapes:
#   Train: (5270, 868, 1)
#   Val:   (565, 868, 1)
#   Test:  (800, 868, 1)
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#  zClass weights: {0: np.float64(2.5), 1: np.float64(0.625)}
#
#  Training Fold 5...
# Epoch 1/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 66s 171ms/step - accuracy: 0.5150 - loss: 0.3860 - val_accuracy: 0.7965 - val_loss: 0.3416
# Epoch 2/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 143ms/step - accuracy: 0.5195 - loss: 0.3665 - val_accuracy: 0.7823 - val_loss: 0.3288
# Epoch 3/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 142ms/step - accuracy: 0.6061 - loss: 0.3338 - val_accuracy: 0.8212 - val_loss: 0.2864
# Epoch 4/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 143ms/step - accuracy: 0.7564 - loss: 0.2601 - val_accuracy: 0.9168 - val_loss: 0.1897
# Epoch 5/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 20s 119ms/step - accuracy: 0.9423 - loss: 0.1189 - val_accuracy: 0.9451 - val_loss: 0.1231
# Epoch 6/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 21s 128ms/step - accuracy: 0.9696 - loss: 0.0741 - val_accuracy: 0.9327 - val_loss: 0.1420
# Epoch 7/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9681 - loss: 0.0757 - val_accuracy: 0.9274 - val_loss: 0.1462
# Epoch 8/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 109ms/step - accuracy: 0.9736 - loss: 0.0616 - val_accuracy: 0.9345 - val_loss: 0.1418
# Epoch 9/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 18s 107ms/step - accuracy: 0.9837 - loss: 0.0528 - val_accuracy: 0.9416 - val_loss: 0.1268
# Epoch 10/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 131ms/step - accuracy: 0.9852 - loss: 0.0460 - val_accuracy: 0.9451 - val_loss: 0.1200
# Epoch 11/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 130ms/step - accuracy: 0.9822 - loss: 0.0444 - val_accuracy: 0.9434 - val_loss: 0.1202
# Epoch 12/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - accuracy: 0.9818 - loss: 0.0462 - val_accuracy: 0.9434 - val_loss: 0.1183
# Epoch 13/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 141ms/step - accuracy: 0.9841 - loss: 0.0360 - val_accuracy: 0.9487 - val_loss: 0.1244
# Epoch 14/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 147ms/step - accuracy: 0.9787 - loss: 0.0403 - val_accuracy: 0.9504 - val_loss: 0.1047
# Epoch 15/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 39s 131ms/step - accuracy: 0.9894 - loss: 0.0312 - val_accuracy: 0.9487 - val_loss: 0.1078
# Epoch 16/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 135ms/step - accuracy: 0.9899 - loss: 0.0309 - val_accuracy: 0.9522 - val_loss: 0.1097
# Epoch 17/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 133ms/step - accuracy: 0.9814 - loss: 0.0423 - val_accuracy: 0.9469 - val_loss: 0.1266
# Epoch 18/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 134ms/step - accuracy: 0.9875 - loss: 0.0299 - val_accuracy: 0.9558 - val_loss: 0.1121
# Epoch 19/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 131ms/step - accuracy: 0.9846 - loss: 0.0353 - val_accuracy: 0.9717 - val_loss: 0.0583
# Epoch 20/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 134ms/step - accuracy: 0.9837 - loss: 0.0320 - val_accuracy: 0.9558 - val_loss: 0.0912
# Epoch 21/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - accuracy: 0.9907 - loss: 0.0188 - val_accuracy: 0.9664 - val_loss: 0.0757
# Epoch 22/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 17s 102ms/step - accuracy: 0.9886 - loss: 0.0215 - val_accuracy: 0.9611 - val_loss: 0.0852
# Epoch 23/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 21s 126ms/step - accuracy: 0.9911 - loss: 0.0172 - val_accuracy: 0.9664 - val_loss: 0.0982
# Epoch 24/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 133ms/step - accuracy: 0.9939 - loss: 0.0182 - val_accuracy: 0.9699 - val_loss: 0.0675
# Epoch 25/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 134ms/step - accuracy: 0.9901 - loss: 0.0196 - val_accuracy: 0.9681 - val_loss: 0.0769
# Epoch 26/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - accuracy: 0.9894 - loss: 0.0215 - val_accuracy: 0.9646 - val_loss: 0.0865
# Epoch 27/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 134ms/step - accuracy: 0.9934 - loss: 0.0153 - val_accuracy: 0.9699 - val_loss: 0.0642
# Epoch 28/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 134ms/step - accuracy: 0.9935 - loss: 0.0135 - val_accuracy: 0.9681 - val_loss: 0.0825
# Epoch 29/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 136ms/step - accuracy: 0.9905 - loss: 0.0190 - val_accuracy: 0.9699 - val_loss: 0.0868
# Epoch 30/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 131ms/step - accuracy: 0.9924 - loss: 0.0158 - val_accuracy: 0.9681 - val_loss: 0.0871
# Epoch 31/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 131ms/step - accuracy: 0.9905 - loss: 0.0154 - val_accuracy: 0.9735 - val_loss: 0.0804
# Epoch 32/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 131ms/step - accuracy: 0.9922 - loss: 0.0137 - val_accuracy: 0.9611 - val_loss: 0.1179
# Epoch 33/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - accuracy: 0.9937 - loss: 0.0129 - val_accuracy: 0.9788 - val_loss: 0.0481
# Epoch 34/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 143ms/step - accuracy: 0.9930 - loss: 0.0145 - val_accuracy: 0.9717 - val_loss: 0.0790
# Epoch 35/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 158ms/step - accuracy: 0.9951 - loss: 0.0111 - val_accuracy: 0.9752 - val_loss: 0.0813
# Epoch 36/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 156ms/step - accuracy: 0.9956 - loss: 0.0108 - val_accuracy: 0.9752 - val_loss: 0.0719
# Epoch 37/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 25s 152ms/step - accuracy: 0.9913 - loss: 0.0166 - val_accuracy: 0.9752 - val_loss: 0.0580
# Epoch 38/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 23s 140ms/step - accuracy: 0.9913 - loss: 0.0165 - val_accuracy: 0.9805 - val_loss: 0.0631
# Epoch 39/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 144ms/step - accuracy: 0.9928 - loss: 0.0134 - val_accuracy: 0.9823 - val_loss: 0.0451
# Epoch 40/40
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 24s 144ms/step - accuracy: 0.9935 - loss: 0.0128 - val_accuracy: 0.9752 - val_loss: 0.0776
#
#  Fold 5 - Test Accuracy: 0.9737
#  Weights saved to results(Ictal)\cnn_lstm_fold5.weights.h5
#
# ============================================================
#  FINAL RESULTS
# ============================================================
# Mean Accuracy across all folds: 0.9692 ± 0.0087
# Accuracy per fold: ['0.9638', '0.9663', '0.9837', '0.9588', '0.9737']
#  Overall Metrics (All Folds Combined):
#   Accuracy : 0.9692
#   Precision: 0.9652
#   Recall   : 0.9975
#   F1-score : 0.9811
#
#  CNN+LSTM Training Completed!

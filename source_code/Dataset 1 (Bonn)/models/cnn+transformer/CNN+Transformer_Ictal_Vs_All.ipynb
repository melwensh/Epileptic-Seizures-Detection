# %%
import os
import gc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv1D, MaxPooling1D, Dense, Dropout, LayerNormalization, MultiHeadAttention,
    BatchNormalization, GlobalAveragePooling1D, Reshape, Multiply, 
    SpatialDropout1D, Concatenate, Add, GlobalMaxPooling1D, Activation
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

PREPROCESSING_DIR = r"Preprocessing_Updated_Kfold"
N_FOLDS = 5
RESULTS_DIR = "results_Ictal_vs_All"
os.makedirs(RESULTS_DIR, exist_ok=True)

def mixup_batch(X, y, alpha=0.2):
    indices = np.arange(len(X))
    np.random.shuffle(indices)
    
    lam = np.random.beta(alpha, alpha, size=len(X)).astype(np.float32)
    
    if X.ndim == 2:
        lam_x = lam.reshape((len(X), 1))
    else:
        lam_x = lam.reshape((len(X), 1, 1))
    
    X_mix = X * lam_x + X[indices] * (1 - lam_x)
    
    y = np.array(y, dtype=np.float32)
    original_y_ndim = y.ndim
    y_reshaped = y.reshape((len(y), 1)) 
    lam_y = lam.reshape((len(X), 1))
    
    y_mix = y_reshaped * lam_y + y_reshaped[indices] * (1 - lam_y)
    
    if original_y_ndim == 1:
        y_mix = y_mix.flatten()
        
    return X_mix, y_mix

def augment_batch_advanced(X, y):
    X_aug, y_aug = [], []
    
    for i in range(len(X)):
        shift = np.random.randint(-5, 5)
        scale = np.random.uniform(0.97, 1.03)
        noise = np.random.normal(0, 0.005, X[i].shape).astype(np.float32)
        
        signal_mod = np.roll(X[i] + noise, shift) * scale
        
        X_aug.append(X[i])       
        y_aug.append(y[i])
        X_aug.append(signal_mod) 
        y_aug.append(y[i])
        
    X_aug = np.array(X_aug, dtype=np.float32)
    y_aug = np.array(y_aug, dtype=np.float32)
    
    X_mix, y_mix = mixup_batch(X_aug, y_aug)
    
    X_final = np.concatenate([X_aug, X_mix], axis=0)
    y_final = np.concatenate([y_aug, y_mix], axis=0)
    
    return X_final, y_final

def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x)
    x = Dropout(dropout)(x)
    res = Add()([x, inputs]) 

    x = LayerNormalization(epsilon=1e-6)(res)
    x = Conv1D(ff_dim, kernel_size=1, activation="relu")(x)
    x = Dropout(dropout)(x)
    x = Conv1D(inputs.shape[-1], kernel_size=1)(x)
    x = Add()([x, res]) 
    return x

def inception_module(input_tensor, filters=32):
    conv1 = Conv1D(filters, kernel_size=3, padding='same', activation='relu')(input_tensor)
    conv2 = Conv1D(filters, kernel_size=5, padding='same', activation='relu')(input_tensor)
    conv3 = Conv1D(filters, kernel_size=11, padding='same', activation='relu')(input_tensor)
    pool = MaxPooling1D(3, strides=1, padding='same')(input_tensor)
    conv_pool = Conv1D(filters, kernel_size=1, padding='same', activation='relu')(pool)
    return Concatenate(axis=-1)([conv1, conv2, conv3, conv_pool])

def squeeze_excitation_block(input_tensor, ratio=4):
    channels = input_tensor.shape[-1]
    squeeze = GlobalAveragePooling1D()(input_tensor)
    excitation = Dense(channels // ratio, activation='relu')(squeeze)
    excitation = Dense(channels, activation='sigmoid')(excitation)
    excitation = Reshape((1, channels))(excitation)
    return Multiply()([input_tensor, excitation])

def build_inception_transformer(input_length):
    inputs = Input(shape=(input_length, 1))

    x = inception_module(inputs, filters=16)
    x = BatchNormalization()(x)
    x = squeeze_excitation_block(x)
    x = MaxPooling1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x = inception_module(x, filters=32)
    x = BatchNormalization()(x)
    x = squeeze_excitation_block(x)
    x = MaxPooling1D(2)(x)
    x = SpatialDropout1D(0.15)(x)

    x = inception_module(x, filters=64)
    x = BatchNormalization()(x)
    x = squeeze_excitation_block(x)
    x = MaxPooling1D(2)(x)
    x = SpatialDropout1D(0.2)(x)

    x = transformer_encoder(x, head_size=64, num_heads=4, ff_dim=128, dropout=0.2)
    
    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)
    x = Concatenate()([avg_pool, max_pool])
    
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.4)(x)
    outputs = Dense(1, activation='sigmoid')(x)

    model = Model(inputs, outputs, name="Inception_Transformer_IctalVsAll")
    
    model.compile(
        optimizer=Adam(1e-4),
        loss=tf.keras.losses.BinaryCrossentropy(label_smoothing=0.1),
        metrics=['accuracy']
    )
    return model

def predict_with_tta(model, X_test, iterations=4):
    preds = model.predict(X_test, verbose=0)
    for _ in range(iterations):
        X_aug = []
        for i in range(len(X_test)):
            shift = np.random.randint(-3, 3) 
            scale = np.random.uniform(0.98, 1.02)
            aug_sig = np.roll(X_test[i], shift) * scale
            X_aug.append(aug_sig)
        preds += model.predict(np.array(X_aug), verbose=0)
    return preds / (iterations + 1)

def plot_classification_report_heatmap(y_true, y_pred, title, save_path):
    report = classification_report(y_true, y_pred, target_names=['NON-SEIZURE', 'SEIZURE'], output_dict=True)
    report_df = pd.DataFrame(report).iloc[:-1, :].T
    plt.figure(figsize=(8, 5))
    sns.heatmap(report_df, annot=True, cmap='RdYlGn', fmt='.4f', cbar=True)
    plt.title(title)
    plt.tight_layout()
    plt.savefig(save_path)
    plt.close()

acc_per_fold = []
conf_matrices = []
all_y_true = []
all_y_pred = []

for fold_no in range(N_FOLDS):
    print(f"\n{'='*60}\nFold {fold_no + 1}/{N_FOLDS} (Ictal vs All)\n{'='*60}")
    
    checkpoint_path = os.path.join(RESULTS_DIR, f"best_model_fold{fold_no + 1}.keras")

    X_train_full = np.load(os.path.join(PREPROCESSING_DIR, f"fold_{fold_no}_X_train.npy"), allow_pickle=True).astype(np.float32)
    y_train_full = np.load(os.path.join(PREPROCESSING_DIR, f"fold_{fold_no}_y_train.npy"), allow_pickle=True).astype(np.int32)
    X_test = np.load(os.path.join(PREPROCESSING_DIR, f"fold_{fold_no}_X_test.npy"), allow_pickle=True).astype(np.float32)
    y_test = np.load(os.path.join(PREPROCESSING_DIR, f"fold_{fold_no}_y_test.npy"), allow_pickle=True).astype(np.int32)
    
    ictal_label = np.max(y_train_full) 
    print(f"Detected Ictal Label ID: {ictal_label} (Setting this to 1, others to 0)")
    
    y_train_full_bin = np.where(y_train_full == ictal_label, 1, 0)
    y_test_bin = np.where(y_test == ictal_label, 1, 0)

    X_train, X_val, y_train, y_val = train_test_split(
        X_train_full, y_train_full_bin, 
        test_size=0.1765, stratify=y_train_full_bin, random_state=42
    )

    print("APPLYING MIXUP AUGMENTATION...")
    X_train, y_train = augment_batch_advanced(X_train, y_train)
    
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

    model = build_inception_transformer(X_train.shape[1])
    
    callbacks = [
        ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, mode='min', verbose=1),
        EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, min_lr=1e-6)
    ]

    model.fit(X_train, y_train, epochs=60, batch_size=32, validation_data=(X_val, y_val), callbacks=callbacks, verbose=1)

    print(f"Loading best weights & Evaluating Fold {fold_no + 1}...")
    model.load_weights(checkpoint_path)
    
    y_probs = predict_with_tta(model, X_test)
    y_pred = (y_probs > 0.5).astype(int).flatten()
    
    acc = np.mean(y_pred == y_test_bin)
    print(f"Accuracy: {acc:.4f}")
    acc_per_fold.append(acc)
    
    all_y_true.extend(y_test_bin)
    all_y_pred.extend(y_pred)
    
    conf_matrices.append(confusion_matrix(y_test_bin, y_pred))
    
    plot_classification_report_heatmap(
        y_test_bin, y_pred, 
        f"Fold {fold_no + 1} Report", 
        os.path.join(RESULTS_DIR, f"report_fold{fold_no + 1}.png")
    )
    
    K.clear_session()
    gc.collect()

print(f"\nFINAL MEAN ACCURACY (ICTAL VS ALL): {np.mean(acc_per_fold):.4f} += {np.std(acc_per_fold):.4f}")

total_cm = np.sum(conf_matrices, axis=0)
plt.figure(figsize=(6, 5))
sns.heatmap(total_cm, annot=True, fmt='d', cmap='Blues', xticklabels=['NON-SEIZURE', 'SEIZURE'], yticklabels=['NON-SEIZURE', 'SEIZURE'])
plt.title("Overall Confusion Matrix")
plt.savefig(os.path.join(RESULTS_DIR, "overall_conf_matrix.png"))
plt.show()

print("\nOverall Classification Report:")
print(classification_report(all_y_true, all_y_pred, target_names=['NON-SEIZURE', 'SEIZURE']))

plot_classification_report_heatmap(
    all_y_true, all_y_pred, 
    "Overall Consolidated Report", 
    os.path.join(RESULTS_DIR, "overall_classification_report.png")
)
# Out:
# ============================================================
# Fold 1/5 (Ictal vs All)
# ============================================================
# Detected Ictal Label ID: 2 (Setting this to 1, others to 0)
# APPLYING MIXUP AUGMENTATION...
# Epoch 1/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.7072 - loss: 0.5657
# Epoch 1: val_loss improved from None to 0.29267, saving model to results_Ictal_vs_All\best_model_fold1.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 116s 316ms/step - accuracy: 0.7544 - loss: 0.4435 - val_accuracy: 0.9451 - val_loss: 0.2927 - learning_rate: 1.0000e-04
# Epoch 2/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.8091 - loss: 0.3257
# Epoch 2: val_loss improved from 0.29267 to 0.25153, saving model to results_Ictal_vs_All\best_model_fold1.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 104s 315ms/step - accuracy: 0.8162 - loss: 0.3147 - val_accuracy: 0.9770 - val_loss: 0.2515 - learning_rate: 1.0000e-04
# Epoch 3/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.8279 - loss: 0.2924
# Epoch 3: val_loss improved from 0.25153 to 0.24672, saving model to results_Ictal_vs_All\best_model_fold1.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 103s 313ms/step - accuracy: 0.8267 - loss: 0.2926 - val_accuracy: 0.9823 - val_loss: 0.2467 - learning_rate: 1.0000e-04
# Epoch 4/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.8358 - loss: 0.2791
# Epoch 4: val_loss improved from 0.24672 to 0.22890, saving model to results_Ictal_vs_All\best_model_fold1.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 103s 311ms/step - accuracy: 0.8340 - loss: 0.2772 - val_accuracy: 0.9929 - val_loss: 0.2289 - learning_rate: 1.0000e-04
# Epoch 5/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.8389 - loss: 0.2703
# Epoch 5: val_loss improved from 0.22890 to 0.21958, saving model to results_Ictal_vs_All\best_model_fold1.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 104s 315ms/step - accuracy: 0.8361 - loss: 0.2694 - val_accuracy: 0.9965 - val_loss: 0.2196 - learning_rate: 1.0000e-04
# Epoch 6/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.8341 - loss: 0.2634
# Epoch 6: val_loss improved from 0.21958 to 0.21016, saving model to results_Ictal_vs_All\best_model_fold1.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 104s 316ms/step - accuracy: 0.8390 - loss: 0.2610 - val_accuracy: 0.9965 - val_loss: 0.2102 - learning_rate: 1.0000e-04
# Epoch 7/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.8453 - loss: 0.2569
# Epoch 7: val_loss improved from 0.21016 to 0.20661, saving model to results_Ictal_vs_All\best_model_fold1.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 142s 317ms/step - accuracy: 0.8409 - loss: 0.2556 - val_accuracy: 0.9982 - val_loss: 0.2066 - learning_rate: 1.0000e-04
# Epoch 8/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.8393 - loss: 0.2532
# Epoch 8: val_loss improved from 0.20661 to 0.20564, saving model to results_Ictal_vs_All\best_model_fold1.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 103s 311ms/step - accuracy: 0.8420 - loss: 0.2502 - val_accuracy: 0.9982 - val_loss: 0.2056 - learning_rate: 1.0000e-04
# Epoch 9/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.8314 - loss: 0.2519
# Epoch 9: val_loss did not improve from 0.20564
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 102s 309ms/step - accuracy: 0.8419 - loss: 0.2484 - val_accuracy: 0.9982 - val_loss: 0.2062 - learning_rate: 1.0000e-04
# Epoch 10/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.8390 - loss: 0.2473
# Epoch 10: val_loss did not improve from 0.20564
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 102s 310ms/step - accuracy: 0.8427 - loss: 0.2456 - val_accuracy: 0.9947 - val_loss: 0.2093 - learning_rate: 1.0000e-04
# Epoch 11/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.8425 - loss: 0.2447
# Epoch 11: val_loss improved from 0.20564 to 0.20532, saving model to results_Ictal_vs_All\best_model_fold1.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 143s 311ms/step - accuracy: 0.8425 - loss: 0.2441 - val_accuracy: 0.9982 - val_loss: 0.2053 - learning_rate: 1.0000e-04
# Epoch 12/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.8508 - loss: 0.2409
# Epoch 12: val_loss improved from 0.20532 to 0.20409, saving model to results_Ictal_vs_All\best_model_fold1.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 102s 310ms/step - accuracy: 0.8427 - loss: 0.2424 - val_accuracy: 0.9982 - val_loss: 0.2041 - learning_rate: 1.0000e-04
# Epoch 13/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.8422 - loss: 0.2426
# Epoch 13: val_loss did not improve from 0.20409
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 102s 310ms/step - accuracy: 0.8424 - loss: 0.2421 - val_accuracy: 0.9982 - val_loss: 0.2052 - learning_rate: 1.0000e-04
# Epoch 14/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.8376 - loss: 0.2447
# Epoch 14: val_loss did not improve from 0.20409
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 142s 309ms/step - accuracy: 0.8438 - loss: 0.2410 - val_accuracy: 0.9982 - val_loss: 0.2069 - learning_rate: 1.0000e-04
# Epoch 15/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.8403 - loss: 0.2432
# Epoch 15: val_loss did not improve from 0.20409
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 102s 310ms/step - accuracy: 0.8435 - loss: 0.2402 - val_accuracy: 0.9982 - val_loss: 0.2057 - learning_rate: 1.0000e-04
# Epoch 16/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.8444 - loss: 0.2385
# Epoch 16: val_loss did not improve from 0.20409
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 149s 332ms/step - accuracy: 0.8435 - loss: 0.2391 - val_accuracy: 0.9982 - val_loss: 0.2051 - learning_rate: 1.0000e-04
# Epoch 17/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.8408 - loss: 0.2398
# Epoch 17: val_loss did not improve from 0.20409
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 115s 350ms/step - accuracy: 0.8439 - loss: 0.2374 - val_accuracy: 0.9982 - val_loss: 0.2051 - learning_rate: 5.0000e-05
# Epoch 18/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.8484 - loss: 0.2367
# Epoch 18: val_loss did not improve from 0.20409
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 114s 345ms/step - accuracy: 0.8436 - loss: 0.2378 - val_accuracy: 0.9982 - val_loss: 0.2044 - learning_rate: 5.0000e-05
# Epoch 19/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.8444 - loss: 0.2368
# Epoch 19: val_loss did not improve from 0.20409
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 113s 341ms/step - accuracy: 0.8441 - loss: 0.2372 - val_accuracy: 0.9982 - val_loss: 0.2056 - learning_rate: 5.0000e-05
# Epoch 20/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.8442 - loss: 0.2367
# Epoch 20: val_loss did not improve from 0.20409
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 110s 334ms/step - accuracy: 0.8438 - loss: 0.2371 - val_accuracy: 0.9982 - val_loss: 0.2064 - learning_rate: 5.0000e-05
# Epoch 21/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.8432 - loss: 0.2375
# Epoch 21: val_loss did not improve from 0.20409
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 109s 329ms/step - accuracy: 0.8441 - loss: 0.2366 - val_accuracy: 0.9982 - val_loss: 0.2050 - learning_rate: 2.5000e-05
# Epoch 22/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8382 - loss: 0.2399
# Epoch 22: val_loss did not improve from 0.20409
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 144s 336ms/step - accuracy: 0.8437 - loss: 0.2373 - val_accuracy: 0.9982 - val_loss: 0.2056 - learning_rate: 2.5000e-05
# Loading best weights & Evaluating Fold 1...
# Accuracy: 0.9988
# WARNING:tensorflow:From d:\anaconda\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
#
# ============================================================
# Fold 2/5 (Ictal vs All)
# ============================================================
# Detected Ictal Label ID: 2 (Setting this to 1, others to 0)
# APPLYING MIXUP AUGMENTATION...
# Epoch 1/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.6678 - loss: 0.7166
# Epoch 1: val_loss improved from None to 0.31425, saving model to results_Ictal_vs_All\best_model_fold2.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 124s 341ms/step - accuracy: 0.7428 - loss: 0.4923 - val_accuracy: 0.9398 - val_loss: 0.3142 - learning_rate: 1.0000e-04
# Epoch 2/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.8080 - loss: 0.3297
# Epoch 2: val_loss improved from 0.31425 to 0.25862, saving model to results_Ictal_vs_All\best_model_fold2.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 114s 345ms/step - accuracy: 0.8125 - loss: 0.3203 - val_accuracy: 0.9664 - val_loss: 0.2586 - learning_rate: 1.0000e-04
# Epoch 3/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.8262 - loss: 0.3010
# Epoch 3: val_loss improved from 0.25862 to 0.23591, saving model to results_Ictal_vs_All\best_model_fold2.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 140s 337ms/step - accuracy: 0.8255 - loss: 0.2955 - val_accuracy: 0.9929 - val_loss: 0.2359 - learning_rate: 1.0000e-04
# Epoch 4/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.8265 - loss: 0.2879
# Epoch 4: val_loss improved from 0.23591 to 0.21974, saving model to results_Ictal_vs_All\best_model_fold2.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 112s 338ms/step - accuracy: 0.8296 - loss: 0.2823 - val_accuracy: 0.9965 - val_loss: 0.2197 - learning_rate: 1.0000e-04
# Epoch 5/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.8324 - loss: 0.2719
# Epoch 5: val_loss improved from 0.21974 to 0.21297, saving model to results_Ictal_vs_All\best_model_fold2.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 114s 346ms/step - accuracy: 0.8350 - loss: 0.2694 - val_accuracy: 0.9947 - val_loss: 0.2130 - learning_rate: 1.0000e-04
# Epoch 6/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.8339 - loss: 0.2633
# Epoch 6: val_loss improved from 0.21297 to 0.20835, saving model to results_Ictal_vs_All\best_model_fold2.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 112s 340ms/step - accuracy: 0.8370 - loss: 0.2626 - val_accuracy: 0.9965 - val_loss: 0.2083 - learning_rate: 1.0000e-04
# Epoch 7/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.8400 - loss: 0.2570
# Epoch 7: val_loss did not improve from 0.20835
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 114s 345ms/step - accuracy: 0.8386 - loss: 0.2569 - val_accuracy: 0.9947 - val_loss: 0.2139 - learning_rate: 1.0000e-04
# Epoch 8/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.8394 - loss: 0.2527
# Epoch 8: val_loss improved from 0.20835 to 0.20721, saving model to results_Ictal_vs_All\best_model_fold2.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 115s 348ms/step - accuracy: 0.8399 - loss: 0.2519 - val_accuracy: 0.9982 - val_loss: 0.2072 - learning_rate: 1.0000e-04
# Epoch 9/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.8442 - loss: 0.2499
# Epoch 9: val_loss did not improve from 0.20721
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 118s 358ms/step - accuracy: 0.8407 - loss: 0.2503 - val_accuracy: 0.9982 - val_loss: 0.2090 - learning_rate: 1.0000e-04
# Epoch 10/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.8411 - loss: 0.2478
# Epoch 10: val_loss improved from 0.20721 to 0.20396, saving model to results_Ictal_vs_All\best_model_fold2.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 120s 364ms/step - accuracy: 0.8406 - loss: 0.2480 - val_accuracy: 1.0000 - val_loss: 0.2040 - learning_rate: 1.0000e-04
# Epoch 11/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.8429 - loss: 0.2462
# Epoch 11: val_loss did not improve from 0.20396
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 124s 377ms/step - accuracy: 0.8422 - loss: 0.2459 - val_accuracy: 0.9982 - val_loss: 0.2064 - learning_rate: 1.0000e-04
# Epoch 12/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.8449 - loss: 0.2438
# Epoch 12: val_loss did not improve from 0.20396
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 144s 383ms/step - accuracy: 0.8422 - loss: 0.2444 - val_accuracy: 0.9982 - val_loss: 0.2053 - learning_rate: 1.0000e-04
# Epoch 13/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.8405 - loss: 0.2440
# Epoch 13: val_loss did not improve from 0.20396
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 136s 411ms/step - accuracy: 0.8417 - loss: 0.2444 - val_accuracy: 1.0000 - val_loss: 0.2044 - learning_rate: 1.0000e-04
# Epoch 14/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.8371 - loss: 0.2441
# Epoch 14: val_loss did not improve from 0.20396
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 145s 421ms/step - accuracy: 0.8422 - loss: 0.2426 - val_accuracy: 1.0000 - val_loss: 0.2091 - learning_rate: 1.0000e-04
# Epoch 15/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.8464 - loss: 0.2405
# Epoch 15: val_loss did not improve from 0.20396
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 151s 447ms/step - accuracy: 0.8432 - loss: 0.2414 - val_accuracy: 0.9982 - val_loss: 0.2056 - learning_rate: 5.0000e-05
# Epoch 16/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.8385 - loss: 0.2426
# Epoch 16: val_loss improved from 0.20396 to 0.20241, saving model to results_Ictal_vs_All\best_model_fold2.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 166s 502ms/step - accuracy: 0.8431 - loss: 0.2407 - val_accuracy: 1.0000 - val_loss: 0.2024 - learning_rate: 5.0000e-05
# Epoch 17/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - accuracy: 0.8439 - loss: 0.2397
# Epoch 17: val_loss did not improve from 0.20241
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 180s 545ms/step - accuracy: 0.8431 - loss: 0.2407 - val_accuracy: 0.9982 - val_loss: 0.2061 - learning_rate: 5.0000e-05
# Epoch 18/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 586ms/step - accuracy: 0.8402 - loss: 0.2395
# Epoch 18: val_loss did not improve from 0.20241
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 196s 594ms/step - accuracy: 0.8432 - loss: 0.2400 - val_accuracy: 1.0000 - val_loss: 0.2041 - learning_rate: 5.0000e-05
# Epoch 19/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.8379 - loss: 0.2404
# Epoch 19: val_loss improved from 0.20241 to 0.20203, saving model to results_Ictal_vs_All\best_model_fold2.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 151s 457ms/step - accuracy: 0.8429 - loss: 0.2401 - val_accuracy: 1.0000 - val_loss: 0.2020 - learning_rate: 5.0000e-05
# Epoch 20/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.8428 - loss: 0.2416
# Epoch 20: val_loss did not improve from 0.20203
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 157s 321ms/step - accuracy: 0.8429 - loss: 0.2392 - val_accuracy: 0.9982 - val_loss: 0.2046 - learning_rate: 5.0000e-05
# Epoch 21/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.8434 - loss: 0.2401
# Epoch 21: val_loss did not improve from 0.20203
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 109s 330ms/step - accuracy: 0.8433 - loss: 0.2389 - val_accuracy: 0.9982 - val_loss: 0.2047 - learning_rate: 5.0000e-05
# Epoch 22/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.8464 - loss: 0.2384
# Epoch 22: val_loss did not improve from 0.20203
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 106s 320ms/step - accuracy: 0.8429 - loss: 0.2394 - val_accuracy: 0.9982 - val_loss: 0.2036 - learning_rate: 5.0000e-05
# Epoch 23/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.8420 - loss: 0.2379
# Epoch 23: val_loss did not improve from 0.20203
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 143s 323ms/step - accuracy: 0.8430 - loss: 0.2386 - val_accuracy: 0.9982 - val_loss: 0.2061 - learning_rate: 5.0000e-05
# Epoch 24/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.8518 - loss: 0.2356
# Epoch 24: val_loss did not improve from 0.20203
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 110s 332ms/step - accuracy: 0.8432 - loss: 0.2376 - val_accuracy: 0.9982 - val_loss: 0.2049 - learning_rate: 2.5000e-05
# Epoch 25/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.8436 - loss: 0.2391
# Epoch 25: val_loss did not improve from 0.20203
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 109s 330ms/step - accuracy: 0.8435 - loss: 0.2374 - val_accuracy: 0.9982 - val_loss: 0.2074 - learning_rate: 2.5000e-05
# Epoch 26/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.8457 - loss: 0.2390
# Epoch 26: val_loss did not improve from 0.20203
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 109s 331ms/step - accuracy: 0.8433 - loss: 0.2379 - val_accuracy: 0.9982 - val_loss: 0.2070 - learning_rate: 2.5000e-05
# Epoch 27/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.8451 - loss: 0.2375
# Epoch 27: val_loss did not improve from 0.20203
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 110s 332ms/step - accuracy: 0.8431 - loss: 0.2369 - val_accuracy: 0.9982 - val_loss: 0.2040 - learning_rate: 2.5000e-05
# Epoch 28/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.8453 - loss: 0.2380
# Epoch 28: val_loss did not improve from 0.20203
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 109s 331ms/step - accuracy: 0.8433 - loss: 0.2373 - val_accuracy: 0.9982 - val_loss: 0.2044 - learning_rate: 1.2500e-05
# Epoch 29/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8439 - loss: 0.2369
# Epoch 29: val_loss did not improve from 0.20203
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 110s 334ms/step - accuracy: 0.8433 - loss: 0.2372 - val_accuracy: 0.9982 - val_loss: 0.2052 - learning_rate: 1.2500e-05
# Loading best weights & Evaluating Fold 2...
# Accuracy: 0.9925
#
# ============================================================
# Fold 3/5 (Ictal vs All)
# ============================================================
# Detected Ictal Label ID: 2 (Setting this to 1, others to 0)
# APPLYING MIXUP AUGMENTATION...
# Epoch 1/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.6343 - loss: 0.8636
# Epoch 1: val_loss improved from None to 0.30802, saving model to results_Ictal_vs_All\best_model_fold3.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 122s 338ms/step - accuracy: 0.7296 - loss: 0.5359 - val_accuracy: 0.9770 - val_loss: 0.3080 - learning_rate: 1.0000e-04
# Epoch 2/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8051 - loss: 0.3334
# Epoch 2: val_loss improved from 0.30802 to 0.23728, saving model to results_Ictal_vs_All\best_model_fold3.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 111s 337ms/step - accuracy: 0.8120 - loss: 0.3232 - val_accuracy: 0.9805 - val_loss: 0.2373 - learning_rate: 1.0000e-04
# Epoch 3/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8223 - loss: 0.3017
# Epoch 3: val_loss improved from 0.23728 to 0.22680, saving model to results_Ictal_vs_All\best_model_fold3.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 139s 328ms/step - accuracy: 0.8230 - loss: 0.2973 - val_accuracy: 0.9912 - val_loss: 0.2268 - learning_rate: 1.0000e-04
# Epoch 4/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.8320 - loss: 0.2838
# Epoch 4: val_loss improved from 0.22680 to 0.22334, saving model to results_Ictal_vs_All\best_model_fold3.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 141s 324ms/step - accuracy: 0.8317 - loss: 0.2800 - val_accuracy: 0.9894 - val_loss: 0.2233 - learning_rate: 1.0000e-04
# Epoch 5/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.8360 - loss: 0.2677
# Epoch 5: val_loss improved from 0.22334 to 0.21667, saving model to results_Ictal_vs_All\best_model_fold3.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 112s 339ms/step - accuracy: 0.8359 - loss: 0.2672 - val_accuracy: 0.9912 - val_loss: 0.2167 - learning_rate: 1.0000e-04
# Epoch 6/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8385 - loss: 0.2611
# Epoch 6: val_loss improved from 0.21667 to 0.21060, saving model to results_Ictal_vs_All\best_model_fold3.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 111s 335ms/step - accuracy: 0.8378 - loss: 0.2610 - val_accuracy: 0.9965 - val_loss: 0.2106 - learning_rate: 1.0000e-04
# Epoch 7/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.8408 - loss: 0.2548
# Epoch 7: val_loss improved from 0.21060 to 0.20877, saving model to results_Ictal_vs_All\best_model_fold3.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 109s 332ms/step - accuracy: 0.8395 - loss: 0.2554 - val_accuracy: 0.9929 - val_loss: 0.2088 - learning_rate: 1.0000e-04
# Epoch 8/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8388 - loss: 0.2539
# Epoch 8: val_loss improved from 0.20877 to 0.20714, saving model to results_Ictal_vs_All\best_model_fold3.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 110s 335ms/step - accuracy: 0.8390 - loss: 0.2524 - val_accuracy: 0.9982 - val_loss: 0.2071 - learning_rate: 1.0000e-04
# Epoch 9/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.8380 - loss: 0.2501
# Epoch 9: val_loss did not improve from 0.20714
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 111s 337ms/step - accuracy: 0.8405 - loss: 0.2481 - val_accuracy: 0.9965 - val_loss: 0.2095 - learning_rate: 1.0000e-04
# Epoch 10/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.8423 - loss: 0.2480
# Epoch 10: val_loss did not improve from 0.20714
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 112s 339ms/step - accuracy: 0.8416 - loss: 0.2456 - val_accuracy: 1.0000 - val_loss: 0.2072 - learning_rate: 1.0000e-04
# Epoch 11/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.8411 - loss: 0.2462
# Epoch 11: val_loss improved from 0.20714 to 0.20607, saving model to results_Ictal_vs_All\best_model_fold3.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 110s 333ms/step - accuracy: 0.8423 - loss: 0.2439 - val_accuracy: 1.0000 - val_loss: 0.2061 - learning_rate: 1.0000e-04
# Epoch 12/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.8462 - loss: 0.2393
# Epoch 12: val_loss did not improve from 0.20607
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 110s 333ms/step - accuracy: 0.8433 - loss: 0.2411 - val_accuracy: 1.0000 - val_loss: 0.2154 - learning_rate: 1.0000e-04
# Epoch 13/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8404 - loss: 0.2439
# Epoch 13: val_loss improved from 0.20607 to 0.20436, saving model to results_Ictal_vs_All\best_model_fold3.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 143s 336ms/step - accuracy: 0.8426 - loss: 0.2421 - val_accuracy: 1.0000 - val_loss: 0.2044 - learning_rate: 1.0000e-04
# Epoch 14/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.8433 - loss: 0.2405
# Epoch 14: val_loss did not improve from 0.20436
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 113s 341ms/step - accuracy: 0.8436 - loss: 0.2397 - val_accuracy: 1.0000 - val_loss: 0.2046 - learning_rate: 1.0000e-04
# Epoch 15/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.8426 - loss: 0.2389
# Epoch 15: val_loss did not improve from 0.20436
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 113s 342ms/step - accuracy: 0.8436 - loss: 0.2392 - val_accuracy: 0.9965 - val_loss: 0.2114 - learning_rate: 1.0000e-04
# Epoch 16/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.8417 - loss: 0.2402
# Epoch 16: val_loss did not improve from 0.20436
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 113s 342ms/step - accuracy: 0.8433 - loss: 0.2390 - val_accuracy: 1.0000 - val_loss: 0.2045 - learning_rate: 1.0000e-04
# Epoch 17/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.8414 - loss: 0.2392
# Epoch 17: val_loss improved from 0.20436 to 0.20399, saving model to results_Ictal_vs_All\best_model_fold3.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 114s 345ms/step - accuracy: 0.8436 - loss: 0.2383 - val_accuracy: 1.0000 - val_loss: 0.2040 - learning_rate: 1.0000e-04
# Epoch 18/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.8446 - loss: 0.2374
# Epoch 18: val_loss did not improve from 0.20399
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 140s 339ms/step - accuracy: 0.8436 - loss: 0.2379 - val_accuracy: 1.0000 - val_loss: 0.2050 - learning_rate: 1.0000e-04
# Epoch 19/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.8455 - loss: 0.2386
# Epoch 19: val_loss did not improve from 0.20399
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 113s 343ms/step - accuracy: 0.8441 - loss: 0.2371 - val_accuracy: 1.0000 - val_loss: 0.2063 - learning_rate: 1.0000e-04
# Epoch 20/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.8438 - loss: 0.2367
# Epoch 20: val_loss did not improve from 0.20399
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 113s 344ms/step - accuracy: 0.8444 - loss: 0.2364 - val_accuracy: 1.0000 - val_loss: 0.2095 - learning_rate: 1.0000e-04
# Epoch 21/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.8440 - loss: 0.2360
# Epoch 21: val_loss did not improve from 0.20399
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 114s 345ms/step - accuracy: 0.8438 - loss: 0.2372 - val_accuracy: 1.0000 - val_loss: 0.2113 - learning_rate: 1.0000e-04
# Epoch 22/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.8397 - loss: 0.2358
# Epoch 22: val_loss did not improve from 0.20399
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 114s 345ms/step - accuracy: 0.8439 - loss: 0.2360 - val_accuracy: 0.9982 - val_loss: 0.2053 - learning_rate: 5.0000e-05
# Epoch 23/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.8406 - loss: 0.2363
# Epoch 23: val_loss did not improve from 0.20399
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 115s 347ms/step - accuracy: 0.8442 - loss: 0.2354 - val_accuracy: 0.9982 - val_loss: 0.2072 - learning_rate: 5.0000e-05
# Epoch 24/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.8467 - loss: 0.2360
# Epoch 24: val_loss did not improve from 0.20399
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 115s 349ms/step - accuracy: 0.8441 - loss: 0.2353 - val_accuracy: 0.9982 - val_loss: 0.2080 - learning_rate: 5.0000e-05
# Epoch 25/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.8459 - loss: 0.2353
# Epoch 25: val_loss did not improve from 0.20399
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 116s 351ms/step - accuracy: 0.8441 - loss: 0.2353 - val_accuracy: 1.0000 - val_loss: 0.2053 - learning_rate: 5.0000e-05
# Epoch 26/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.8484 - loss: 0.2354
# Epoch 26: val_loss did not improve from 0.20399
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 141s 347ms/step - accuracy: 0.8443 - loss: 0.2344 - val_accuracy: 1.0000 - val_loss: 0.2095 - learning_rate: 2.5000e-05
# Epoch 27/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.8460 - loss: 0.2336
# Epoch 27: val_loss did not improve from 0.20399
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 115s 347ms/step - accuracy: 0.8442 - loss: 0.2346 - val_accuracy: 1.0000 - val_loss: 0.2069 - learning_rate: 2.5000e-05
# Loading best weights & Evaluating Fold 3...
# Accuracy: 1.0000
#
# ============================================================
# Fold 4/5 (Ictal vs All)
# ============================================================
# Detected Ictal Label ID: 2 (Setting this to 1, others to 0)
# APPLYING MIXUP AUGMENTATION...
# Epoch 1/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.6576 - loss: 0.7405
# Epoch 1: val_loss improved from None to 0.40783, saving model to results_Ictal_vs_All\best_model_fold4.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 130s 361ms/step - accuracy: 0.7342 - loss: 0.5114 - val_accuracy: 0.8460 - val_loss: 0.4078 - learning_rate: 1.0000e-04
# Epoch 2/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.8076 - loss: 0.3328
# Epoch 2: val_loss improved from 0.40783 to 0.25094, saving model to results_Ictal_vs_All\best_model_fold4.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 116s 351ms/step - accuracy: 0.8141 - loss: 0.3193 - val_accuracy: 0.9770 - val_loss: 0.2509 - learning_rate: 1.0000e-04
# Epoch 3/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.8282 - loss: 0.2952
# Epoch 3: val_loss improved from 0.25094 to 0.23721, saving model to results_Ictal_vs_All\best_model_fold4.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 119s 361ms/step - accuracy: 0.8275 - loss: 0.2932 - val_accuracy: 0.9912 - val_loss: 0.2372 - learning_rate: 1.0000e-04
# Epoch 4/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.8350 - loss: 0.2805
# Epoch 4: val_loss improved from 0.23721 to 0.22749, saving model to results_Ictal_vs_All\best_model_fold4.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 124s 375ms/step - accuracy: 0.8332 - loss: 0.2803 - val_accuracy: 0.9929 - val_loss: 0.2275 - learning_rate: 1.0000e-04
# Epoch 5/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.8405 - loss: 0.2705
# Epoch 5: val_loss improved from 0.22749 to 0.22162, saving model to results_Ictal_vs_All\best_model_fold4.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 113s 343ms/step - accuracy: 0.8359 - loss: 0.2714 - val_accuracy: 0.9929 - val_loss: 0.2216 - learning_rate: 1.0000e-04
# Epoch 6/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.8404 - loss: 0.2605
# Epoch 6: val_loss improved from 0.22162 to 0.21888, saving model to results_Ictal_vs_All\best_model_fold4.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 115s 347ms/step - accuracy: 0.8403 - loss: 0.2609 - val_accuracy: 0.9929 - val_loss: 0.2189 - learning_rate: 1.0000e-04
# Epoch 7/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.8371 - loss: 0.2613
# Epoch 7: val_loss improved from 0.21888 to 0.21113, saving model to results_Ictal_vs_All\best_model_fold4.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 113s 343ms/step - accuracy: 0.8401 - loss: 0.2581 - val_accuracy: 0.9947 - val_loss: 0.2111 - learning_rate: 1.0000e-04
# Epoch 8/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.8425 - loss: 0.2555
# Epoch 8: val_loss did not improve from 0.21113
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 119s 359ms/step - accuracy: 0.8415 - loss: 0.2539 - val_accuracy: 0.9947 - val_loss: 0.2141 - learning_rate: 1.0000e-04
# Epoch 9/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.8392 - loss: 0.2547
# Epoch 9: val_loss improved from 0.21113 to 0.20857, saving model to results_Ictal_vs_All\best_model_fold4.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 136s 340ms/step - accuracy: 0.8407 - loss: 0.2531 - val_accuracy: 0.9965 - val_loss: 0.2086 - learning_rate: 1.0000e-04
# Epoch 10/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.8409 - loss: 0.2490
# Epoch 10: val_loss improved from 0.20857 to 0.20821, saving model to results_Ictal_vs_All\best_model_fold4.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 114s 346ms/step - accuracy: 0.8425 - loss: 0.2487 - val_accuracy: 0.9947 - val_loss: 0.2082 - learning_rate: 1.0000e-04
# Epoch 11/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.8398 - loss: 0.2485
# Epoch 11: val_loss did not improve from 0.20821
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 114s 346ms/step - accuracy: 0.8431 - loss: 0.2472 - val_accuracy: 0.9965 - val_loss: 0.2106 - learning_rate: 1.0000e-04
# Epoch 12/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.8420 - loss: 0.2433
# Epoch 12: val_loss did not improve from 0.20821
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 114s 347ms/step - accuracy: 0.8435 - loss: 0.2443 - val_accuracy: 0.9965 - val_loss: 0.2091 - learning_rate: 1.0000e-04
# Epoch 13/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.8435 - loss: 0.2429
# Epoch 13: val_loss did not improve from 0.20821
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 137s 414ms/step - accuracy: 0.8435 - loss: 0.2438 - val_accuracy: 0.9965 - val_loss: 0.2094 - learning_rate: 1.0000e-04
# Epoch 14/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.8437 - loss: 0.2419
# Epoch 14: val_loss did not improve from 0.20821
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 129s 390ms/step - accuracy: 0.8435 - loss: 0.2428 - val_accuracy: 0.9965 - val_loss: 0.2113 - learning_rate: 1.0000e-04
# Epoch 15/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.8416 - loss: 0.2420
# Epoch 15: val_loss improved from 0.20821 to 0.20637, saving model to results_Ictal_vs_All\best_model_fold4.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 127s 386ms/step - accuracy: 0.8444 - loss: 0.2405 - val_accuracy: 0.9965 - val_loss: 0.2064 - learning_rate: 5.0000e-05
# Epoch 16/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.8467 - loss: 0.2411
# Epoch 16: val_loss did not improve from 0.20637
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 129s 391ms/step - accuracy: 0.8446 - loss: 0.2407 - val_accuracy: 0.9965 - val_loss: 0.2087 - learning_rate: 5.0000e-05
# Epoch 17/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.8424 - loss: 0.2407
# Epoch 17: val_loss did not improve from 0.20637
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 128s 388ms/step - accuracy: 0.8446 - loss: 0.2399 - val_accuracy: 0.9965 - val_loss: 0.2094 - learning_rate: 5.0000e-05
# Epoch 18/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.8385 - loss: 0.2426
# Epoch 18: val_loss improved from 0.20637 to 0.20502, saving model to results_Ictal_vs_All\best_model_fold4.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 130s 395ms/step - accuracy: 0.8447 - loss: 0.2396 - val_accuracy: 0.9965 - val_loss: 0.2050 - learning_rate: 5.0000e-05
# Epoch 19/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.8469 - loss: 0.2389
# Epoch 19: val_loss did not improve from 0.20502
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 130s 393ms/step - accuracy: 0.8451 - loss: 0.2391 - val_accuracy: 0.9965 - val_loss: 0.2068 - learning_rate: 5.0000e-05
# Epoch 20/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.8413 - loss: 0.2393
# Epoch 20: val_loss did not improve from 0.20502
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 145s 401ms/step - accuracy: 0.8449 - loss: 0.2392 - val_accuracy: 0.9965 - val_loss: 0.2087 - learning_rate: 5.0000e-05
# Epoch 21/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.8498 - loss: 0.2380
# Epoch 21: val_loss did not improve from 0.20502
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 138s 389ms/step - accuracy: 0.8447 - loss: 0.2388 - val_accuracy: 0.9965 - val_loss: 0.2059 - learning_rate: 5.0000e-05
# Epoch 22/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.8457 - loss: 0.2373
# Epoch 22: val_loss did not improve from 0.20502
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 131s 397ms/step - accuracy: 0.8443 - loss: 0.2387 - val_accuracy: 0.9965 - val_loss: 0.2079 - learning_rate: 5.0000e-05
# Epoch 23/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.8440 - loss: 0.2390
# Epoch 23: val_loss did not improve from 0.20502
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 131s 397ms/step - accuracy: 0.8451 - loss: 0.2379 - val_accuracy: 0.9965 - val_loss: 0.2068 - learning_rate: 2.5000e-05
# Epoch 24/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.8436 - loss: 0.2375
# Epoch 24: val_loss did not improve from 0.20502
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 131s 397ms/step - accuracy: 0.8453 - loss: 0.2375 - val_accuracy: 0.9965 - val_loss: 0.2078 - learning_rate: 2.5000e-05
# Epoch 25/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.8452 - loss: 0.2364
# Epoch 25: val_loss did not improve from 0.20502
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 144s 404ms/step - accuracy: 0.8452 - loss: 0.2376 - val_accuracy: 0.9965 - val_loss: 0.2081 - learning_rate: 2.5000e-05
# Epoch 26/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.8437 - loss: 0.2372
# Epoch 26: val_loss did not improve from 0.20502
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 131s 398ms/step - accuracy: 0.8445 - loss: 0.2379 - val_accuracy: 0.9947 - val_loss: 0.2088 - learning_rate: 2.5000e-05
# Epoch 27/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.8449 - loss: 0.2376
# Epoch 27: val_loss did not improve from 0.20502
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.8451 - loss: 0.2370 - val_accuracy: 0.9947 - val_loss: 0.2091 - learning_rate: 1.2500e-05
# Epoch 28/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.8408 - loss: 0.2368
# Epoch 28: val_loss did not improve from 0.20502
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 132s 401ms/step - accuracy: 0.8452 - loss: 0.2364 - val_accuracy: 0.9965 - val_loss: 0.2074 - learning_rate: 1.2500e-05
# Loading best weights & Evaluating Fold 4...
# Accuracy: 0.9988
#
# ============================================================
# Fold 5/5 (Ictal vs All)
# ============================================================
# Detected Ictal Label ID: 2 (Setting this to 1, others to 0)
# APPLYING MIXUP AUGMENTATION...
# Epoch 1/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.7089 - loss: 0.5307
# Epoch 1: val_loss improved from None to 0.28590, saving model to results_Ictal_vs_All\best_model_fold5.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 149s 406ms/step - accuracy: 0.7651 - loss: 0.4161 - val_accuracy: 0.9504 - val_loss: 0.2859 - learning_rate: 1.0000e-04
# Epoch 2/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.8071 - loss: 0.3185
# Epoch 2: val_loss improved from 0.28590 to 0.24148, saving model to results_Ictal_vs_All\best_model_fold5.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 132s 399ms/step - accuracy: 0.8201 - loss: 0.3067 - val_accuracy: 0.9876 - val_loss: 0.2415 - learning_rate: 1.0000e-04
# Epoch 3/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.8221 - loss: 0.2895
# Epoch 3: val_loss improved from 0.24148 to 0.23116, saving model to results_Ictal_vs_All\best_model_fold5.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 133s 404ms/step - accuracy: 0.8285 - loss: 0.2861 - val_accuracy: 0.9947 - val_loss: 0.2312 - learning_rate: 1.0000e-04
# Epoch 4/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.8336 - loss: 0.2742
# Epoch 4: val_loss improved from 0.23116 to 0.21992, saving model to results_Ictal_vs_All\best_model_fold5.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 135s 408ms/step - accuracy: 0.8335 - loss: 0.2727 - val_accuracy: 0.9965 - val_loss: 0.2199 - learning_rate: 1.0000e-04
# Epoch 5/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.8369 - loss: 0.2676
# Epoch 5: val_loss improved from 0.21992 to 0.21480, saving model to results_Ictal_vs_All\best_model_fold5.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 139s 399ms/step - accuracy: 0.8370 - loss: 0.2634 - val_accuracy: 0.9982 - val_loss: 0.2148 - learning_rate: 1.0000e-04
# Epoch 6/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.8429 - loss: 0.2564
# Epoch 6: val_loss improved from 0.21480 to 0.20860, saving model to results_Ictal_vs_All\best_model_fold5.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 137s 415ms/step - accuracy: 0.8399 - loss: 0.2566 - val_accuracy: 0.9965 - val_loss: 0.2086 - learning_rate: 1.0000e-04
# Epoch 7/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.8325 - loss: 0.2552
# Epoch 7: val_loss improved from 0.20860 to 0.20614, saving model to results_Ictal_vs_All\best_model_fold5.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 137s 401ms/step - accuracy: 0.8399 - loss: 0.2512 - val_accuracy: 0.9982 - val_loss: 0.2061 - learning_rate: 1.0000e-04
# Epoch 8/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.8391 - loss: 0.2490
# Epoch 8: val_loss improved from 0.20614 to 0.20497, saving model to results_Ictal_vs_All\best_model_fold5.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 142s 400ms/step - accuracy: 0.8415 - loss: 0.2481 - val_accuracy: 0.9982 - val_loss: 0.2050 - learning_rate: 1.0000e-04
# Epoch 9/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.8376 - loss: 0.2447
# Epoch 9: val_loss did not improve from 0.20497
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 143s 402ms/step - accuracy: 0.8424 - loss: 0.2441 - val_accuracy: 1.0000 - val_loss: 0.2055 - learning_rate: 1.0000e-04
# Epoch 10/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.8470 - loss: 0.2417
# Epoch 10: val_loss did not improve from 0.20497
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 134s 406ms/step - accuracy: 0.8419 - loss: 0.2438 - val_accuracy: 0.9982 - val_loss: 0.2084 - learning_rate: 1.0000e-04
# Epoch 11/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.8365 - loss: 0.2428
# Epoch 11: val_loss did not improve from 0.20497
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 142s 407ms/step - accuracy: 0.8428 - loss: 0.2417 - val_accuracy: 0.9982 - val_loss: 0.2067 - learning_rate: 1.0000e-04
# Epoch 12/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.8400 - loss: 0.2415
# Epoch 12: val_loss did not improve from 0.20497
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 145s 416ms/step - accuracy: 0.8428 - loss: 0.2417 - val_accuracy: 1.0000 - val_loss: 0.2052 - learning_rate: 1.0000e-04
# Epoch 13/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.8394 - loss: 0.2418
# Epoch 13: val_loss improved from 0.20497 to 0.20363, saving model to results_Ictal_vs_All\best_model_fold5.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 136s 412ms/step - accuracy: 0.8431 - loss: 0.2402 - val_accuracy: 1.0000 - val_loss: 0.2036 - learning_rate: 5.0000e-05
# Epoch 14/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.8486 - loss: 0.2375
# Epoch 14: val_loss improved from 0.20363 to 0.20254, saving model to results_Ictal_vs_All\best_model_fold5.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 136s 414ms/step - accuracy: 0.8431 - loss: 0.2392 - val_accuracy: 1.0000 - val_loss: 0.2025 - learning_rate: 5.0000e-05
# Epoch 15/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.8472 - loss: 0.2388
# Epoch 15: val_loss improved from 0.20254 to 0.20252, saving model to results_Ictal_vs_All\best_model_fold5.keras
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 141s 410ms/step - accuracy: 0.8435 - loss: 0.2387 - val_accuracy: 1.0000 - val_loss: 0.2025 - learning_rate: 5.0000e-05
# Epoch 16/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.8445 - loss: 0.2389
# Epoch 16: val_loss did not improve from 0.20252
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 136s 411ms/step - accuracy: 0.8435 - loss: 0.2388 - val_accuracy: 1.0000 - val_loss: 0.2031 - learning_rate: 5.0000e-05
# Epoch 17/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.8412 - loss: 0.2380
# Epoch 17: val_loss did not improve from 0.20252
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 136s 412ms/step - accuracy: 0.8433 - loss: 0.2383 - val_accuracy: 1.0000 - val_loss: 0.2065 - learning_rate: 5.0000e-05
# Epoch 18/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.8405 - loss: 0.2405
# Epoch 18: val_loss did not improve from 0.20252
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 146s 423ms/step - accuracy: 0.8430 - loss: 0.2389 - val_accuracy: 1.0000 - val_loss: 0.2051 - learning_rate: 5.0000e-05
# Epoch 19/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.8447 - loss: 0.2389
# Epoch 19: val_loss did not improve from 0.20252
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 135s 410ms/step - accuracy: 0.8435 - loss: 0.2374 - val_accuracy: 1.0000 - val_loss: 0.2033 - learning_rate: 2.5000e-05
# Epoch 20/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.8466 - loss: 0.2365
# Epoch 20: val_loss did not improve from 0.20252
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 137s 414ms/step - accuracy: 0.8435 - loss: 0.2373 - val_accuracy: 1.0000 - val_loss: 0.2051 - learning_rate: 2.5000e-05
# Epoch 21/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.8474 - loss: 0.2368
# Epoch 21: val_loss did not improve from 0.20252
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 137s 416ms/step - accuracy: 0.8436 - loss: 0.2372 - val_accuracy: 1.0000 - val_loss: 0.2037 - learning_rate: 2.5000e-05
# Epoch 22/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.8412 - loss: 0.2371
# Epoch 22: val_loss did not improve from 0.20252
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 136s 413ms/step - accuracy: 0.8435 - loss: 0.2372 - val_accuracy: 1.0000 - val_loss: 0.2052 - learning_rate: 2.5000e-05
# Epoch 23/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.8477 - loss: 0.2371
# Epoch 23: val_loss did not improve from 0.20252
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 143s 415ms/step - accuracy: 0.8437 - loss: 0.2368 - val_accuracy: 1.0000 - val_loss: 0.2037 - learning_rate: 1.2500e-05
# Epoch 24/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.8428 - loss: 0.2369
# Epoch 24: val_loss did not improve from 0.20252
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 137s 414ms/step - accuracy: 0.8438 - loss: 0.2367 - val_accuracy: 1.0000 - val_loss: 0.2035 - learning_rate: 1.2500e-05
# Epoch 25/60
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.8462 - loss: 0.2367
# Epoch 25: val_loss did not improve from 0.20252
# 330/330 ━━━━━━━━━━━━━━━━━━━━ 146s 424ms/step - accuracy: 0.8437 - loss: 0.2365 - val_accuracy: 1.0000 - val_loss: 0.2033 - learning_rate: 1.2500e-05
# Loading best weights & Evaluating Fold 5...
# Accuracy: 0.9950
#
# FINAL MEAN ACCURACY (ICTAL VS ALL): 0.9970 ± 0.0028
# Overall Classification Report:
#               precision    recall  f1-score   support
#
#  NON-SEIZURE       1.00      1.00      1.00      3200
#      SEIZURE       1.00      0.98      0.99       800
#
#     accuracy                           1.00      4000
#    macro avg       1.00      0.99      1.00      4000
# weighted avg       1.00      1.00      1.00      4000

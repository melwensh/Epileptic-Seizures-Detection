# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf /content/local_data
# !mkdir -p /content/local_data


# !rsync -ah --info=progress2 "/content/drive/MyDrive/gp_dataset/fusion_raw_and_5x5_v4/" "/content/local_data"
# Out:
#          48.07G 100%   36.95MB/s    0:20:40 (xfr#270, to-chk=0/271)

# %%
import os, glob, gc, pickle
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, roc_curve
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv1D, Conv2D, BatchNormalization, Activation,
                                     MaxPooling1D, GlobalAveragePooling1D, GlobalAveragePooling2D,
                                     Dense, Dropout, Concatenate, GaussianNoise,
                                     LayerNormalization, MultiHeadAttention, Reshape)
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

local_path = '/content/local_data'
RESULTS_DIR = '/content/drive/MyDrive/gp_dataset/model_results_v4_fusion'
os.makedirs(RESULTS_DIR, exist_ok=True)

MODEL_OUT = f'{RESULTS_DIR}/Gatekeeper_Fusion_Transformer_v4.h5'

class FusionDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, save_dir, split_name, batch_size=128, shuffle=True, **kwargs):
        super().__init__(**kwargs)

        self.save_dir = save_dir
        self.split_name = split_name
        self.batch_size = batch_size
        self.shuffle = shuffle

        self.raw_files = sorted(glob.glob(f'{save_dir}/X_raw_{self.split_name.lower()}_part*.npy'))
        if not self.raw_files:
            self.raw_files = sorted(glob.glob(f'{save_dir}/X_raw_{self.split_name.upper()}_part*.npy'))

        self.eng_files = sorted(glob.glob(f'{save_dir}/X_eng_{self.split_name.lower()}_part*.npy'))
        if not self.eng_files:
            self.eng_files = sorted(glob.glob(f'{save_dir}/X_eng_{self.split_name.upper()}_part*.npy'))

        self.y_files = sorted(glob.glob(f'{save_dir}/y_{self.split_name.lower()}_part*.npy'))
        if not self.y_files:
            self.y_files = sorted(glob.glob(f'{save_dir}/y_{self.split_name.upper()}_part*.npy'))

        if len(self.raw_files) == 0:
            raise FileNotFoundError()

        self.file_batch_counts = []
        for yf in self.y_files:
            length = len(np.load(yf, mmap_mode='r'))
            self.file_batch_counts.append(int(np.ceil(length / self.batch_size)))

        self.file_indices = np.arange(len(self.raw_files))
        self.batch_map = []
        self.on_epoch_end()

    def __len__(self):
        return int(sum(self.file_batch_counts))

    def on_epoch_end(self):
        self.batch_map = []
        if self.shuffle:
            np.random.shuffle(self.file_indices)

        for f_idx in self.file_indices:
            num_batches = self.file_batch_counts[f_idx]
            batch_order = np.arange(num_batches)
            if self.shuffle:
                np.random.shuffle(batch_order)
            for b_idx in batch_order:
                self.batch_map.append((f_idx, b_idx))

    def __getitem__(self, index):
        f_idx, b_idx = self.batch_map[index]

        X_raw = np.load(self.raw_files[f_idx], mmap_mode='r')
        X_eng = np.load(self.eng_files[f_idx], mmap_mode='r')
        y_tmp = np.load(self.y_files[f_idx], mmap_mode='r')

        start = b_idx * self.batch_size
        end = start + self.batch_size

        y_batch = np.where(y_tmp[start:end] == 'bckg', 0, 1)

        X_raw_batch = np.array(X_raw[start:end])
        X_eng_batch = np.array(X_eng[start:end])

        return (X_raw_batch, X_eng_batch), y_batch


print("Initializing Data Generators...")
train_gen = FusionDataGenerator(local_path, "train", batch_size=128, shuffle=True)
val_gen = FusionDataGenerator(local_path, "val", batch_size=128, shuffle=False)
test_gen = FusionDataGenerator(local_path, "test", batch_size=128, shuffle=False)

print(f"Generators Ready. Train Batches: {len(train_gen)}, Val Batches: {len(val_gen)}")


def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0.1):
    x = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(inputs, inputs)
    x = Dropout(dropout)(x)
    x = LayerNormalization(epsilon=1e-6)(inputs + x)
    res = Dense(ff_dim, activation="relu")(x)
    res = Dropout(dropout)(res)
    res = Dense(inputs.shape[-1])(res)
    x = LayerNormalization(epsilon=1e-6)(x + res)
    return x


def build_transformer_fusion(raw_shape=(1280, 20), eng_shape=(5, 5, 15)):
    input_raw = Input(shape=raw_shape, name="Raw_Input")
    r = GaussianNoise(0.02)(input_raw)
    r = Conv1D(64, 15, strides=4, padding='same')(r)

    r = transformer_encoder(r, head_size=64, num_heads=4, ff_dim=128, dropout=0.1)
    r = transformer_encoder(r, head_size=64, num_heads=4, ff_dim=128, dropout=0.1)
    r = GlobalAveragePooling1D()(r)

    input_eng = Input(shape=eng_shape, name="Engineered_Input")
    e = Reshape((eng_shape[0] * eng_shape[1], eng_shape[2]))(input_eng)
    e = Dense(32)(e)

    e = transformer_encoder(e, head_size=32, num_heads=2, ff_dim=64, dropout=0.1)
    e = GlobalAveragePooling1D()(e)

    merged = Concatenate()([r, e])
    dense = Dense(64, activation='relu', kernel_regularizer='l2')(merged)
    dense = Dropout(0.5)(dense)
    outputs = Dense(1, activation='sigmoid')(dense)

    return Model(inputs=[input_raw, input_eng], outputs=outputs)


model = build_transformer_fusion()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0003)
model.compile(optimizer=optimizer, loss='binary_crossentropy',
              metrics=['accuracy', tf.keras.metrics.AUC(name='auc'),
                       tf.keras.metrics.Precision(name='precision'),
                       tf.keras.metrics.Recall(name='recall')])


callbacks = [
    EarlyStopping(monitor='val_auc', patience=8, restore_best_weights=True, mode='max', verbose=1),
    ReduceLROnPlateau(monitor='val_auc', factor=0.5, patience=4, min_lr=1e-6, mode='max', verbose=1),
    ModelCheckpoint(MODEL_OUT, monitor='val_auc', save_best_only=True, mode='max', verbose=1)
]

print("\nStarting Transformer Fusion Model Training...")
history = model.fit(train_gen, validation_data=val_gen, epochs=50, callbacks=callbacks, verbose=1)


print("\nEvaluating on Validation Set...")
probs_val = model.predict(test_gen).flatten()

y_val_true = []
for yf in test_gen.y_files:
    y_val_true.extend(np.where(np.load(yf) == 'bckg', 0, 1))
y_val_true = np.array(y_val_true)

fpr, tpr, thresholds = roc_curve(y_val_true, probs_val)
optimal_threshold = thresholds[np.argmax(tpr - fpr)]
preds_val = (probs_val > optimal_threshold).astype(int)

print(f"\nOptimal Threshold: {optimal_threshold:.4f}")
print("\nClassification Report:")
print(classification_report(y_val_true, preds_val, target_names=['Normal', 'Seizure']))

plt.figure(figsize=(7, 5))
sns.heatmap(confusion_matrix(y_val_true, preds_val), annot=True, fmt='d', cmap='Blues',
            xticklabels=['Normal', 'Seizure'], yticklabels=['Normal', 'Seizure'])
plt.title('Transformer Fusion Model Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Initializing Data Generators...
# Generators Ready. Train Batches: 2623, Val Batches: 296
#
# Starting Transformer Fusion Model Training...
# Epoch 1/50
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.7485 - auc: 0.7393 - loss: 0.8876 - precision: 0.6268 - recall: 0.4006
# Epoch 1: val_auc improved from None to 0.79562, saving model to /content/drive/MyDrive/gp_dataset/model_results_v4_fusion/Gatekeeper_Fusion_Transformer_v4.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to /content/drive/MyDrive/gp_dataset/model_results_v4_fusion/Gatekeeper_Fusion_Transformer_v4.h5
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 999s 371ms/step - accuracy: 0.7854 - auc: 0.8179 - loss: 0.6740 - precision: 0.7094 - recall: 0.5319 - val_accuracy: 0.7185 - val_auc: 0.7956 - val_loss: 0.5841 - val_precision: 0.6457 - val_recall: 0.3230 - learning_rate: 3.0000e-04
# Epoch 2/50
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8380 - auc: 0.8881 - loss: 0.4263 - precision: 0.7859 - recall: 0.6765
# Epoch 2: val_auc improved from 0.79562 to 0.84134, saving model to /content/drive/MyDrive/gp_dataset/model_results_v4_fusion/Gatekeeper_Fusion_Transformer_v4.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 2: finished saving model to /content/drive/MyDrive/gp_dataset/model_results_v4_fusion/Gatekeeper_Fusion_Transformer_v4.h5
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 249s 95ms/step - accuracy: 0.8470 - auc: 0.8950 - loss: 0.4011 - precision: 0.7877 - recall: 0.6997 - val_accuracy: 0.7851 - val_auc: 0.8413 - val_loss: 0.5089 - val_precision: 0.6685 - val_recall: 0.6905 - learning_rate: 3.0000e-04
# Epoch 3/50
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8615 - auc: 0.9096 - loss: 0.3603 - precision: 0.8040 - recall: 0.7494
# Epoch 3: val_auc improved from 0.84134 to 0.86240, saving model to /content/drive/MyDrive/gp_dataset/model_results_v4_fusion/Gatekeeper_Fusion_Transformer_v4.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 3: finished saving model to /content/drive/MyDrive/gp_dataset/model_results_v4_fusion/Gatekeeper_Fusion_Transformer_v4.h5
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 249s 95ms/step - accuracy: 0.8684 - auc: 0.9132 - loss: 0.3469 - precision: 0.8163 - recall: 0.7476 - val_accuracy: 0.7666 - val_auc: 0.8624 - val_loss: 0.5018 - val_precision: 0.7846 - val_recall: 0.4023 - learning_rate: 3.0000e-04
# Epoch 4/50
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8855 - auc: 0.9357 - loss: 0.3033 - precision: 0.8450 - recall: 0.7989
# Epoch 4: val_auc improved from 0.86240 to 0.89213, saving model to /content/drive/MyDrive/gp_dataset/model_results_v4_fusion/Gatekeeper_Fusion_Transformer_v4.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 4: finished saving model to /content/drive/MyDrive/gp_dataset/model_results_v4_fusion/Gatekeeper_Fusion_Transformer_v4.h5
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 250s 95ms/step - accuracy: 0.8848 - auc: 0.9292 - loss: 0.3096 - precision: 0.8397 - recall: 0.7811 - val_accuracy: 0.8167 - val_auc: 0.8921 - val_loss: 0.4249 - val_precision: 0.7956 - val_recall: 0.5970 - learning_rate: 3.0000e-04
# Epoch 5/50
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8905 - auc: 0.9363 - loss: 0.2915 - precision: 0.8474 - recall: 0.7918
# Epoch 5: val_auc did not improve from 0.89213
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 250s 95ms/step - accuracy: 0.8876 - auc: 0.9351 - loss: 0.2970 - precision: 0.8405 - recall: 0.7910 - val_accuracy: 0.8264 - val_auc: 0.8886 - val_loss: 0.4164 - val_precision: 0.8172 - val_recall: 0.6094 - learning_rate: 3.0000e-04
# Epoch 6/50
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8974 - auc: 0.9441 - loss: 0.2766 - precision: 0.8591 - recall: 0.8129
# Epoch 6: val_auc improved from 0.89213 to 0.90196, saving model to /content/drive/MyDrive/gp_dataset/model_results_v4_fusion/Gatekeeper_Fusion_Transformer_v4.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 6: finished saving model to /content/drive/MyDrive/gp_dataset/model_results_v4_fusion/Gatekeeper_Fusion_Transformer_v4.h5
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 251s 96ms/step - accuracy: 0.8980 - auc: 0.9440 - loss: 0.2756 - precision: 0.8557 - recall: 0.8107 - val_accuracy: 0.8454 - val_auc: 0.9020 - val_loss: 0.3774 - val_precision: 0.8029 - val_recall: 0.7037 - learning_rate: 3.0000e-04
# Epoch 7/50
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9050 - auc: 0.9516 - loss: 0.2577 - precision: 0.8646 - recall: 0.8370
# Epoch 7: val_auc did not improve from 0.90196
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 250s 95ms/step - accuracy: 0.9037 - auc: 0.9495 - loss: 0.2608 - precision: 0.8623 - recall: 0.8237 - val_accuracy: 0.8151 - val_auc: 0.8753 - val_loss: 0.4232 - val_precision: 0.7722 - val_recall: 0.6224 - learning_rate: 3.0000e-04
# Epoch 8/50
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9107 - auc: 0.9553 - loss: 0.2383 - precision: 0.8639 - recall: 0.8250
# Epoch 8: val_auc did not improve from 0.90196
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 250s 95ms/step - accuracy: 0.9081 - auc: 0.9561 - loss: 0.2467 - precision: 0.8643 - recall: 0.8377 - val_accuracy: 0.7813 - val_auc: 0.8840 - val_loss: 0.5207 - val_precision: 0.8129 - val_recall: 0.4369 - learning_rate: 3.0000e-04
# Epoch 9/50
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9160 - auc: 0.9579 - loss: 0.2316 - precision: 0.8738 - recall: 0.8421
# Epoch 9: val_auc did not improve from 0.90196
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 250s 95ms/step - accuracy: 0.9154 - auc: 0.9613 - loss: 0.2303 - precision: 0.8714 - recall: 0.8559 - val_accuracy: 0.7969 - val_auc: 0.8892 - val_loss: 0.5226 - val_precision: 0.8239 - val_recall: 0.4879 - learning_rate: 3.0000e-04
# Epoch 10/50
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9178 - auc: 0.9617 - loss: 0.2239 - precision: 0.8683 - recall: 0.8564
# Epoch 10: val_auc improved from 0.90196 to 0.90829, saving model to /content/drive/MyDrive/gp_dataset/model_results_v4_fusion/Gatekeeper_Fusion_Transformer_v4.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 10: finished saving model to /content/drive/MyDrive/gp_dataset/model_results_v4_fusion/Gatekeeper_Fusion_Transformer_v4.h5
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 250s 95ms/step - accuracy: 0.9171 - auc: 0.9636 - loss: 0.2246 - precision: 0.8722 - recall: 0.8611 - val_accuracy: 0.8184 - val_auc: 0.9083 - val_loss: 0.4837 - val_precision: 0.8432 - val_recall: 0.5514 - learning_rate: 3.0000e-04
# Epoch 11/50
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9209 - auc: 0.9629 - loss: 0.2204 - precision: 0.8754 - recall: 0.8614
# Epoch 11: val_auc did not improve from 0.90829
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 250s 95ms/step - accuracy: 0.9213 - auc: 0.9657 - loss: 0.2170 - precision: 0.8788 - recall: 0.8682 - val_accuracy: 0.7636 - val_auc: 0.8911 - val_loss: 0.6733 - val_precision: 0.9187 - val_recall: 0.3101 - learning_rate: 3.0000e-04
# Epoch 12/50
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9256 - auc: 0.9674 - loss: 0.2102 - precision: 0.8826 - recall: 0.8833
# Epoch 12: val_auc did not improve from 0.90829
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 250s 95ms/step - accuracy: 0.9259 - auc: 0.9693 - loss: 0.2055 - precision: 0.8809 - recall: 0.8824 - val_accuracy: 0.7692 - val_auc: 0.9004 - val_loss: 0.6135 - val_precision: 0.8592 - val_recall: 0.3583 - learning_rate: 3.0000e-04
# Epoch 13/50
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9265 - auc: 0.9697 - loss: 0.2028 - precision: 0.8840 - recall: 0.8814
# Epoch 13: val_auc did not improve from 0.90829
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 250s 95ms/step - accuracy: 0.9286 - auc: 0.9721 - loss: 0.1970 - precision: 0.8878 - recall: 0.8834 - val_accuracy: 0.7880 - val_auc: 0.8591 - val_loss: 0.6044 - val_precision: 0.7863 - val_recall: 0.4900 - learning_rate: 3.0000e-04
# Epoch 14/50
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9307 - auc: 0.9727 - loss: 0.1896 - precision: 0.8851 - recall: 0.8885
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
#
# Epoch 14: val_auc did not improve from 0.90829
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 250s 95ms/step - accuracy: 0.9304 - auc: 0.9728 - loss: 0.1937 - precision: 0.8855 - recall: 0.8932 - val_accuracy: 0.7844 - val_auc: 0.8735 - val_loss: 0.6689 - val_precision: 0.8211 - val_recall: 0.4419 - learning_rate: 3.0000e-04
# Epoch 15/50
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9437 - auc: 0.9810 - loss: 0.1606 - precision: 0.9074 - recall: 0.9188
# Epoch 15: val_auc did not improve from 0.90829
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 250s 95ms/step - accuracy: 0.9439 - auc: 0.9810 - loss: 0.1599 - precision: 0.9023 - recall: 0.9203 - val_accuracy: 0.8182 - val_auc: 0.8965 - val_loss: 0.5341 - val_precision: 0.8552 - val_recall: 0.5395 - learning_rate: 1.5000e-04
# Epoch 16/50
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9462 - auc: 0.9832 - loss: 0.1515 - precision: 0.9099 - recall: 0.9250
# Epoch 16: val_auc did not improve from 0.90829
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 264s 96ms/step - accuracy: 0.9475 - auc: 0.9833 - loss: 0.1494 - precision: 0.9059 - recall: 0.9287 - val_accuracy: 0.7935 - val_auc: 0.8704 - val_loss: 0.6676 - val_precision: 0.8351 - val_recall: 0.4652 - learning_rate: 1.5000e-04
# Epoch 17/50
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9462 - auc: 0.9816 - loss: 0.1557 - precision: 0.9067 - recall: 0.9292
# Epoch 17: val_auc did not improve from 0.90829
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 250s 95ms/step - accuracy: 0.9490 - auc: 0.9837 - loss: 0.1469 - precision: 0.9084 - recall: 0.9307 - val_accuracy: 0.8066 - val_auc: 0.8779 - val_loss: 0.6029 - val_precision: 0.8234 - val_recall: 0.5258 - learning_rate: 1.5000e-04
# Epoch 18/50
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9531 - auc: 0.9858 - loss: 0.1362 - precision: 0.9135 - recall: 0.9385
# Epoch 18: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
#
# Epoch 18: val_auc did not improve from 0.90829
# 2623/2623 ━━━━━━━━━━━━━━━━━━━━ 249s 95ms/step - accuracy: 0.9506 - auc: 0.9846 - loss: 0.1420 - precision: 0.9092 - recall: 0.9357 - val_accuracy: 0.7441 - val_auc: 0.8168 - val_loss: 0.9458 - val_precision: 0.8328 - val_recall: 0.2795 - learning_rate: 1.5000e-04
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 10.
#
# Evaluating on Validation Set...
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 30s 90ms/step
#
# Optimal Threshold: 0.0562
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.92      0.84      0.88     24976
#      Seizure       0.72      0.86      0.78     12276
#
#     accuracy                           0.84     37252
#    macro avg       0.82      0.85      0.83     37252
# weighted avg       0.86      0.84      0.85     37252

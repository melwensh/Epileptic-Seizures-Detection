# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !mkdir -p /content/local_data


# !rsync -ah --info=progress2 "/content/drive/MyDrive/gp_dataset/classification_v2_split_PSD_features/" "/content/local_data"

# %%
import os, glob, gc, warnings
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv1D, Conv2D, BatchNormalization, Activation,
                                     MaxPooling1D, GlobalAveragePooling1D, GlobalAveragePooling2D,
                                     Dense, Dropout, Concatenate, GaussianNoise, LeakyReLU,
                                     SpatialDropout1D, SpatialDropout2D, LSTM)
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.layers import Add

warnings.filterwarnings('ignore')

TARGET_CLASSES = ['fnsz', 'gnsz', 'cpsz']
LABEL_MAP = {lbl: idx for idx, lbl in enumerate(TARGET_CLASSES)}

DATA_DIR = '/content/local_data'
RESULTS_DIR = '/content/drive/MyDrive/gp_dataset/model_results_3classes_v1_split'
os.makedirs(RESULTS_DIR, exist_ok=True)

MODEL_OUT = f'{RESULTS_DIR}/Seizure_Type_Classifier_v1.h5'

class MultiClassFusionDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, save_dir, split_name, batch_size=64, shuffle=True, **kwargs):
        super().__init__(**kwargs)

        self.save_dir = save_dir
        self.split_name = split_name
        self.batch_size = batch_size
        self.shuffle = shuffle

        self.raw_files = sorted(glob.glob(f'{save_dir}/X_raw_{self.split_name.lower()}_part*.npy'))
        self.eng_files = sorted(glob.glob(f'{save_dir}/X_eng_{self.split_name.lower()}_part*.npy'))
        self.y_files = sorted(glob.glob(f'{save_dir}/y_{self.split_name.lower()}_part*.npy'))

        if len(self.raw_files) == 0:
            available_files = os.listdir(save_dir)[:5] if os.path.exists(save_dir) else "Directory Not Found"
            raise FileNotFoundError(
                f"No files found for split '{self.split_name}' in: {save_dir}\n"
            )

        self.file_batch_counts = []
        for yf in self.y_files:
            length = len(np.load(yf, mmap_mode='r'))
            self.file_batch_counts.append(int(np.ceil(length / self.batch_size)))

        self.file_indices = np.arange(len(self.raw_files))
        self.batch_map = []
        self.on_epoch_end()

    def __len__(self):
        return int(sum(self.file_batch_counts))

    def on_epoch_end(self):
        self.batch_map = []
        if self.shuffle:
            np.random.shuffle(self.file_indices)

        for f_idx in self.file_indices:
            num_batches = self.file_batch_counts[f_idx]
            batch_order = np.arange(num_batches)
            if self.shuffle:
                np.random.shuffle(batch_order)
            for b_idx in batch_order:
                self.batch_map.append((f_idx, b_idx))

    def __getitem__(self, index):
        f_idx, b_idx = self.batch_map[index]

        X_raw = np.load(self.raw_files[f_idx], mmap_mode='r')
        X_eng = np.load(self.eng_files[f_idx], mmap_mode='r')
        y_tmp = np.load(self.y_files[f_idx], mmap_mode='r')

        start = b_idx * self.batch_size
        end = start + self.batch_size

        y_str = np.char.strip(np.char.lower(y_tmp[start:end].astype(str)))
        y_batch = np.array([LABEL_MAP[lbl] for lbl in y_str if lbl in LABEL_MAP])

        y_batch_onehot = to_categorical(y_batch, num_classes=len(TARGET_CLASSES))

        X_raw_batch = np.array(X_raw[start:end])
        X_eng_batch = np.array(X_eng[start:end])

        return (X_raw_batch, X_eng_batch), y_batch_onehot

train_gen = MultiClassFusionDataGenerator(DATA_DIR, "train", batch_size=64, shuffle=True)
val_gen = MultiClassFusionDataGenerator(DATA_DIR, "val", batch_size=64, shuffle=False)
print(f"Data generators initialized. Train batches: {len(train_gen)}, Validation batches: {len(val_gen)}")

def compute_class_weights_safe(generator, split_name):
    print(f"Computing class distribution and weights for {split_name.upper()} set...")
    class_counts = {idx: 0 for idx in range(len(TARGET_CLASSES))}
    total_samples = 0

    for yf in generator.y_files:
        y_tmp = np.load(yf, mmap_mode='r')
        chunk_size = 50000
        for i in range(0, len(y_tmp), chunk_size):
            chunk = y_tmp[i:i+chunk_size]
            chunk_str = np.char.strip(np.char.lower(chunk.astype(str)))

            y_indices = [LABEL_MAP[lbl] for lbl in chunk_str if lbl in LABEL_MAP]
            for idx in y_indices:
                class_counts[idx] += 1
                total_samples += 1

            del chunk, chunk_str, y_indices
        del y_tmp
        gc.collect()

    if total_samples == 0:
        raise ValueError("Zero valid samples detected.")

    for idx, count in class_counts.items():
        percentage = (count / total_samples) * 100
        print(f"{TARGET_CLASSES[idx].upper()}: {count} samples ({percentage:.2f}%)")
    print(f"Total samples: {total_samples}")

    class_weights = {}
    for idx, count in class_counts.items():
        if count > 0:
            class_weights[idx] = total_samples / (len(TARGET_CLASSES) * count)
        else:
            class_weights[idx] = 1.0

    print(f"Computed class weights: {class_weights}")
    return class_weights

train_class_weights = compute_class_weights_safe(train_gen, "Train")
_ = compute_class_weights_safe(val_gen, "Validation")

def build_strong_multiclass_model(raw_shape=(1280, 20), eng_shape=(5, 5, 5), num_classes=3):
    reg = l2(0.002)

    input_raw = Input(shape=raw_shape, name="Raw_Input")
    r = GaussianNoise(0.15)(input_raw)

    r1 = Conv1D(16, kernel_size=15, strides=2, padding='same', kernel_regularizer=reg)(r)
    r1 = LeakyReLU(alpha=0.1)(r1)
    r1 = MaxPooling1D(pool_size=4)(r1)
    r1 = Dropout(0.4)(r1)

    r2 = Conv1D(32, kernel_size=7, padding='same', kernel_regularizer=reg)(r1)
    r2 = LeakyReLU(alpha=0.1)(r2)
    r2 = MaxPooling1D(pool_size=2)(r2)
    r2 = Dropout(0.5)(r2)

    r3 = Conv1D(64, kernel_size=5, padding='same', kernel_regularizer=reg)(r2)
    r3 = LeakyReLU(alpha=0.1)(r3)

    r3 = LSTM(64, return_sequences=False, kernel_regularizer=reg)(r3)
    r3 = Dropout(0.4)(r3)

    input_eng = Input(shape=eng_shape, name="Engineered_Input")
    e = Conv2D(8, (3, 3), padding='same', kernel_regularizer=reg)(input_eng)
    e = LeakyReLU(alpha=0.1)(e)
    e = Dropout(0.1)(e)

    e = Conv2D(16, (3, 3), padding='same', kernel_regularizer=reg)(e)
    e = LeakyReLU(alpha=0.1)(e)
    e = GlobalAveragePooling2D()(e)

    merged = Concatenate()([r3, e])

    dense1 = Dense(32, kernel_regularizer=reg)(merged)
    dense1 = LeakyReLU(alpha=0.1)(dense1)
    dense1 = Dropout(0.6)(dense1)

    dense2 = Dense(64, kernel_regularizer=reg)(dense1)
    dense2 = LeakyReLU(alpha=0.1)(dense2)
    dense2 = Dropout(0.5)(dense2)

    outputs = Dense(num_classes, activation='softmax', name="Output_Classification")(dense2)

    return Model(inputs=[input_raw, input_eng], outputs=outputs)

model = build_strong_multiclass_model(num_classes=len(TARGET_CLASSES))
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.15),
    metrics=['accuracy']
)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, mode='min', verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, min_lr=1e-6, mode='min', verbose=1),
    ModelCheckpoint(MODEL_OUT, monitor='val_loss', save_best_only=True, mode='min', verbose=1)
]

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=60,
    callbacks=callbacks,
    class_weight=train_class_weights,
    verbose=1
)

test_gen = MultiClassFusionDataGenerator(DATA_DIR, "test", batch_size=64, shuffle=False)

probs_test = model.predict(test_gen)
preds_test = np.argmax(probs_test, axis=1)

y_test_true = []
for yf in test_gen.y_files:
    y_tmp = np.load(yf, mmap_mode='r')
    chunk_size = 50000
    for i in range(0, len(y_tmp), chunk_size):
        chunk = y_tmp[i:i+chunk_size]
        y_str = np.char.strip(np.char.lower(chunk.astype(str)))
        y_test_true.extend([LABEL_MAP[lbl] for lbl in y_str if lbl in LABEL_MAP])
        del chunk, y_str
    del y_tmp
    gc.collect()

y_test_true = np.array(y_test_true)

print(classification_report(y_test_true, preds_test, target_names=TARGET_CLASSES))

plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_test_true, preds_test)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=TARGET_CLASSES, yticklabels=TARGET_CLASSES)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Data generators initialized. Train batches: 3601, Validation batches: 700
# Computing class distribution and weights for TRAIN set...
# FNSZ: 89957 samples (40.70%)
# GNSZ: 76002 samples (34.39%)
# CPSZ: 55045 samples (24.91%)
# Total samples: 221004
# Computed class weights: {0: 0.8189245973076025, 1: 0.9692902818346886, 2: 1.3383231901171768}
# Computing class distribution and weights for VALIDATION set...
# FNSZ: 9696 samples (22.43%)
# GNSZ: 18264 samples (42.26%)
# CPSZ: 15263 samples (35.31%)
# Total samples: 43223
# Computed class weights: {0: 1.4859392189218923, 1: 0.7888560373777194, 2: 0.9439603398196074}
# Epoch 1/60
# 3600/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4082 - loss: 1.5074
# Epoch 1: val_loss improved from None to 1.24231, saving model to /content/drive/MyDrive/gp_dataset/model_results_3classes_v1_split/Seizure_Type_Classifier_v1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to /content/drive/MyDrive/gp_dataset/model_results_3classes_v1_split/Seizure_Type_Classifier_v1.h5
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 157s 42ms/step - accuracy: 0.5012 - loss: 1.3370 - val_accuracy: 0.4641 - val_loss: 1.2423 - learning_rate: 1.0000e-04
# Epoch 2/60
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7021 - loss: 1.0447
# Epoch 2: val_loss did not improve from 1.24231
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 144s 40ms/step - accuracy: 0.7385 - loss: 1.0041 - val_accuracy: 0.5518 - val_loss: 1.3132 - learning_rate: 1.0000e-04
# Epoch 3/60
# 3600/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8098 - loss: 0.8933
# Epoch 3: val_loss improved from 1.24231 to 1.04969, saving model to /content/drive/MyDrive/gp_dataset/model_results_3classes_v1_split/Seizure_Type_Classifier_v1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 3: finished saving model to /content/drive/MyDrive/gp_dataset/model_results_3classes_v1_split/Seizure_Type_Classifier_v1.h5
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 143s 40ms/step - accuracy: 0.8211 - loss: 0.8707 - val_accuracy: 0.6798 - val_loss: 1.0497 - learning_rate: 1.0000e-04
# Epoch 4/60
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8554 - loss: 0.8015
# Epoch 4: val_loss did not improve from 1.04969
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 143s 40ms/step - accuracy: 0.8609 - loss: 0.7880 - val_accuracy: 0.6465 - val_loss: 1.0752 - learning_rate: 1.0000e-04
# Epoch 5/60
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8764 - loss: 0.7475
# Epoch 5: val_loss improved from 1.04969 to 0.95013, saving model to /content/drive/MyDrive/gp_dataset/model_results_3classes_v1_split/Seizure_Type_Classifier_v1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 5: finished saving model to /content/drive/MyDrive/gp_dataset/model_results_3classes_v1_split/Seizure_Type_Classifier_v1.h5
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 148s 41ms/step - accuracy: 0.8816 - loss: 0.7368 - val_accuracy: 0.6945 - val_loss: 0.9501 - learning_rate: 1.0000e-04
# Epoch 6/60
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8937 - loss: 0.7062
# Epoch 6: val_loss did not improve from 0.95013
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 147s 41ms/step - accuracy: 0.8940 - loss: 0.7007 - val_accuracy: 0.6537 - val_loss: 1.0865 - learning_rate: 1.0000e-04
# Epoch 7/60
# 3600/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9011 - loss: 0.6815
# Epoch 7: val_loss did not improve from 0.95013
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 145s 40ms/step - accuracy: 0.9019 - loss: 0.6755 - val_accuracy: 0.6797 - val_loss: 1.0362 - learning_rate: 1.0000e-04
# Epoch 8/60
# 3600/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9018 - loss: 0.6641
# Epoch 8: val_loss improved from 0.95013 to 0.84114, saving model to /content/drive/MyDrive/gp_dataset/model_results_3classes_v1_split/Seizure_Type_Classifier_v1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 8: finished saving model to /content/drive/MyDrive/gp_dataset/model_results_3classes_v1_split/Seizure_Type_Classifier_v1.h5
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 145s 40ms/step - accuracy: 0.9093 - loss: 0.6535 - val_accuracy: 0.7405 - val_loss: 0.8411 - learning_rate: 1.0000e-04
# Epoch 9/60
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9190 - loss: 0.6366
# Epoch 9: val_loss did not improve from 0.84114
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 148s 41ms/step - accuracy: 0.9143 - loss: 0.6380 - val_accuracy: 0.7220 - val_loss: 0.8661 - learning_rate: 1.0000e-04
# Epoch 10/60
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9224 - loss: 0.6214
# Epoch 10: val_loss did not improve from 0.84114
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 144s 40ms/step - accuracy: 0.9190 - loss: 0.6247 - val_accuracy: 0.7427 - val_loss: 0.8584 - learning_rate: 1.0000e-04
# Epoch 11/60
# 3599/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9248 - loss: 0.6125
# Epoch 11: val_loss did not improve from 0.84114
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 143s 40ms/step - accuracy: 0.9239 - loss: 0.6115 - val_accuracy: 0.6975 - val_loss: 0.9522 - learning_rate: 1.0000e-04
# Epoch 12/60
# 3600/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9277 - loss: 0.6063
# Epoch 12: val_loss improved from 0.84114 to 0.83194, saving model to /content/drive/MyDrive/gp_dataset/model_results_3classes_v1_split/Seizure_Type_Classifier_v1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 12: finished saving model to /content/drive/MyDrive/gp_dataset/model_results_3classes_v1_split/Seizure_Type_Classifier_v1.h5
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 145s 40ms/step - accuracy: 0.9260 - loss: 0.6047 - val_accuracy: 0.7631 - val_loss: 0.8319 - learning_rate: 1.0000e-04
# Epoch 13/60
# 3600/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9352 - loss: 0.5885
# Epoch 13: val_loss did not improve from 0.83194
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 146s 41ms/step - accuracy: 0.9300 - loss: 0.5933 - val_accuracy: 0.7462 - val_loss: 0.8323 - learning_rate: 1.0000e-04
# Epoch 14/60
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9302 - loss: 0.5840
# Epoch 14: val_loss did not improve from 0.83194
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 148s 41ms/step - accuracy: 0.9322 - loss: 0.5859 - val_accuracy: 0.7231 - val_loss: 0.9335 - learning_rate: 1.0000e-04
# Epoch 15/60
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9323 - loss: 0.5849
# Epoch 15: val_loss did not improve from 0.83194
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 145s 40ms/step - accuracy: 0.9337 - loss: 0.5827 - val_accuracy: 0.7520 - val_loss: 0.8932 - learning_rate: 1.0000e-04
# Epoch 16/60
# 3600/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9387 - loss: 0.5736
# Epoch 16: val_loss improved from 0.83194 to 0.80773, saving model to /content/drive/MyDrive/gp_dataset/model_results_3classes_v1_split/Seizure_Type_Classifier_v1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 16: finished saving model to /content/drive/MyDrive/gp_dataset/model_results_3classes_v1_split/Seizure_Type_Classifier_v1.h5
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 146s 40ms/step - accuracy: 0.9364 - loss: 0.5748 - val_accuracy: 0.7880 - val_loss: 0.8077 - learning_rate: 1.0000e-04
# Epoch 17/60
# 3600/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9354 - loss: 0.5721
# Epoch 17: val_loss did not improve from 0.80773
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 144s 40ms/step - accuracy: 0.9366 - loss: 0.5723 - val_accuracy: 0.7270 - val_loss: 0.9228 - learning_rate: 1.0000e-04
# Epoch 18/60
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9389 - loss: 0.5679
# Epoch 18: val_loss did not improve from 0.80773
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 145s 40ms/step - accuracy: 0.9401 - loss: 0.5650 - val_accuracy: 0.7351 - val_loss: 0.8974 - learning_rate: 1.0000e-04
# Epoch 19/60
# 3600/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9415 - loss: 0.5617
# Epoch 19: val_loss did not improve from 0.80773
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 142s 40ms/step - accuracy: 0.9396 - loss: 0.5638 - val_accuracy: 0.7438 - val_loss: 0.8737 - learning_rate: 1.0000e-04
# Epoch 20/60
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9434 - loss: 0.5558
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 20: val_loss did not improve from 0.80773
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 146s 41ms/step - accuracy: 0.9420 - loss: 0.5577 - val_accuracy: 0.7192 - val_loss: 0.9166 - learning_rate: 1.0000e-04
# Epoch 21/60
# 3600/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9494 - loss: 0.5446
# Epoch 21: val_loss did not improve from 0.80773
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 145s 40ms/step - accuracy: 0.9491 - loss: 0.5441 - val_accuracy: 0.7697 - val_loss: 0.8201 - learning_rate: 5.0000e-05
# Epoch 22/60
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9509 - loss: 0.5410
# Epoch 22: val_loss did not improve from 0.80773
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 158s 44ms/step - accuracy: 0.9503 - loss: 0.5416 - val_accuracy: 0.7730 - val_loss: 0.8177 - learning_rate: 5.0000e-05
# Epoch 23/60
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9504 - loss: 0.5417
# Epoch 23: val_loss did not improve from 0.80773
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 146s 41ms/step - accuracy: 0.9508 - loss: 0.5400 - val_accuracy: 0.7372 - val_loss: 0.9153 - learning_rate: 5.0000e-05
# Epoch 24/60
# 3600/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9551 - loss: 0.5324
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 24: val_loss did not improve from 0.80773
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 145s 40ms/step - accuracy: 0.9523 - loss: 0.5364 - val_accuracy: 0.7262 - val_loss: 0.9344 - learning_rate: 5.0000e-05
# Epoch 25/60
# 3600/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9579 - loss: 0.5266
# Epoch 25: val_loss did not improve from 0.80773
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 145s 40ms/step - accuracy: 0.9543 - loss: 0.5309 - val_accuracy: 0.7877 - val_loss: 0.8137 - learning_rate: 2.5000e-05
# Epoch 26/60
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9543 - loss: 0.5301
# Epoch 26: val_loss did not improve from 0.80773
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 149s 41ms/step - accuracy: 0.9559 - loss: 0.5287 - val_accuracy: 0.7775 - val_loss: 0.8363 - learning_rate: 2.5000e-05
# Epoch 27/60
# 3600/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9587 - loss: 0.5217
# Epoch 27: val_loss did not improve from 0.80773
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 147s 41ms/step - accuracy: 0.9557 - loss: 0.5276 - val_accuracy: 0.7870 - val_loss: 0.8139 - learning_rate: 2.5000e-05
# Epoch 28/60
# 3600/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9590 - loss: 0.5256
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 28: val_loss did not improve from 0.80773
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 147s 41ms/step - accuracy: 0.9570 - loss: 0.5258 - val_accuracy: 0.7714 - val_loss: 0.8404 - learning_rate: 2.5000e-05
# Epoch 29/60
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9585 - loss: 0.5239
# Epoch 29: val_loss did not improve from 0.80773
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 150s 42ms/step - accuracy: 0.9576 - loss: 0.5236 - val_accuracy: 0.7618 - val_loss: 0.8528 - learning_rate: 1.2500e-05
# Epoch 30/60
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9592 - loss: 0.5214
# Epoch 30: val_loss did not improve from 0.80773
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 146s 41ms/step - accuracy: 0.9582 - loss: 0.5224 - val_accuracy: 0.7511 - val_loss: 0.8692 - learning_rate: 1.2500e-05
# Epoch 31/60
# 3600/3601 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9596 - loss: 0.5188
# Epoch 31: val_loss did not improve from 0.80773
# 3601/3601 ━━━━━━━━━━━━━━━━━━━━ 151s 42ms/step - accuracy: 0.9588 - loss: 0.5210 - val_accuracy: 0.7701 - val_loss: 0.8414 - learning_rate: 1.2500e-05
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 16.
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 17s 30ms/step
#               precision    recall  f1-score   support
#
#         fnsz       0.70      0.68      0.69      7536
#         gnsz       0.97      0.71      0.82     14306
#         cpsz       0.68      0.91      0.78     11994
#
#     accuracy                           0.78     33836
#    macro avg       0.79      0.77      0.76     33836
# weighted avg       0.81      0.78      0.78     33836
